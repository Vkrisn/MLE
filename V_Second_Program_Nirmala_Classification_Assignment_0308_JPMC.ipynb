# %% [markdown]
# <a href="https://colab.research.google.com/github/Vkrisn/MLE/blob/main/V_Second_Program_Nirmala_Classification_Assignment_0308_JPMC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import your Libraries
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import sklearn.metrics as metrics
# %matplotlib inline

# %%
# Set the Environment
# Ignore Warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

#Write out the versions of all packages to requirements.txt
# !pip freeze >> requirements.txt

# Remove the restriction on Jupyter that limits the columns displayed (the ... in the middle)
pd.set_option('max_columns',None)
# Docs: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.set_option.html#

# Pretty Display of variables.  for instance, you can call df.head() and df.tail() in the same cell and BOTH display w/o print
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# List of ALL Magic Commands.  To run a magic command %var  --- i.e.:  %env
# %lsmagic
# %env  -- list environment variables
# %%time  -- gives you information about how long a cel took to run
# %%timeit -- runs a cell 100,000 times and then gives you the average time the cell will take to run (can be LONG)
# %pdb -- python debugger

# to display nice model diagram
from sklearn import set_config
set_config(display='diagram')

# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"

print("\n Numpy: " + np.__version__)
print("\n sklearn: " + sklearn.__version__)
# Out:
#  Numpy: 1.22.4
#
#  sklearn: 1.2.1

# %%
## Load data
df = pd.read_csv("./Hotel Reservations.csv")
# %time
df.head(5)
# Out:
# CPU times: user 3 µs, sys: 1 µs, total: 4 µs
# Wall time: 5.72 µs
#   Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0   INN00001             2               0                     1
# 1   INN00002             2               0                     2
# 2   INN00003             1               0                     2
# 3   INN00004             2               0                     0
# 4   INN00005             2               0                     1
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 1                  3      Not Selected                           0
# 2                  1       Meal Plan 1                           0
# 3                  2       Meal Plan 1                           0
# 4                  1      Not Selected                           0
#
#   room_type_reserved  lead_time  arrival_year  arrival_month  arrival_date  \
# 0        Room_Type 1        224          2017             10             2
# 1        Room_Type 1          5          2018             11             6
# 2        Room_Type 1          1          2018              2            28
# 3        Room_Type 1        211          2018              5            20
# 4        Room_Type 1         48          2018              4            11
#
#   market_segment_type  repeated_guest  no_of_previous_cancellations  \
# 0             Offline               0                             0
# 1              Online               0                             0
# 2              Online               0                             0
# 3              Online               0                             0
# 4              Online               0                             0
#
#    no_of_previous_bookings_not_canceled  avg_price_per_room  \
# 0                                     0               65.00
# 1                                     0              106.68
# 2                                     0               60.00
# 3                                     0              100.00
# 4                                     0               94.50
#
#    no_of_special_requests booking_status
# 0                       0   Not_Canceled
# 1                       1   Not_Canceled
# 2                       0       Canceled
# 3                       0       Canceled
# 4                       0       Canceled

# %%
# %timeit
# Show size of the dataset
print("Rows and Columns: \n", df.shape, "\n")
print("General Information: \n", df.info(), "\n")
# b) Validate and change all data types
print(df.dtypes)
# Out:
# Rows and Columns:
#  (36275, 19)
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36275 entries, 0 to 36274
# Data columns (total 19 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Booking_ID                            36275 non-null  object
#  1   no_of_adults                          36275 non-null  int64
#  2   no_of_children                        36275 non-null  int64
#  3   no_of_weekend_nights                  36275 non-null  int64
#  4   no_of_week_nights                     36275 non-null  int64
#  5   type_of_meal_plan                     36275 non-null  object
#  6   required_car_parking_space            36275 non-null  int64
#  7   room_type_reserved                    36275 non-null  object
#  8   lead_time                             36275 non-null  int64
#  9   arrival_year                          36275 non-null  int64
#  10  arrival_month                         36275 non-null  int64
#  11  arrival_date                          36275 non-null  int64
#  12  market_segment_type                   36275 non-null  object
#  13  repeated_guest                        36275 non-null  int64
#  14  no_of_previous_cancellations          36275 non-null  int64
#  15  no_of_previous_bookings_not_canceled  36275 non-null  int64
#  16  avg_price_per_room                    36275 non-null  float64
#  17  no_of_special_requests                36275 non-null  int64
#  18  booking_status                        36275 non-null  object
# dtypes: float64(1), int64(13), object(5)
# memory usage: 5.3+ MB
# General Information:
#  None
#
# Booking_ID                               object
# no_of_adults                              int64
# no_of_children                            int64
# no_of_weekend_nights                      int64
# no_of_week_nights                         int64
# type_of_meal_plan                        object
# required_car_parking_space                int64
# room_type_reserved                       object
# lead_time                                 int64
# arrival_year                              int64
# arrival_month                             int64
# arrival_date                              int64
# market_segment_type                      object
# repeated_guest                            int64
# no_of_previous_cancellations              int64
# no_of_previous_bookings_not_canceled      int64
# avg_price_per_room                      float64
# no_of_special_requests                    int64
# booking_status                           object
# dtype: object

# %%
df.describe()
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# count  36275.000000    36275.000000          36275.000000       36275.000000
# mean       1.844962        0.105279              0.810724           2.204300
# std        0.518715        0.402648              0.870644           1.410905
# min        0.000000        0.000000              0.000000           0.000000
# 25%        2.000000        0.000000              0.000000           1.000000
# 50%        2.000000        0.000000              1.000000           2.000000
# 75%        2.000000        0.000000              2.000000           3.000000
# max        4.000000       10.000000              7.000000          17.000000
#
#        required_car_parking_space     lead_time  arrival_year  arrival_month  \
# count                36275.000000  36275.000000  36275.000000   36275.000000
# mean                     0.030986     85.232557   2017.820427       7.423653
# std                      0.173281     85.930817      0.383836       3.069894
# min                      0.000000      0.000000   2017.000000       1.000000
# 25%                      0.000000     17.000000   2018.000000       5.000000
# 50%                      0.000000     57.000000   2018.000000       8.000000
# 75%                      0.000000    126.000000   2018.000000      10.000000
# max                      1.000000    443.000000   2018.000000      12.000000
#
#        arrival_date  repeated_guest  no_of_previous_cancellations  \
# count  36275.000000    36275.000000                  36275.000000
# mean      15.596995        0.025637                      0.023349
# std        8.740447        0.158053                      0.368331
# min        1.000000        0.000000                      0.000000
# 25%        8.000000        0.000000                      0.000000
# 50%       16.000000        0.000000                      0.000000
# 75%       23.000000        0.000000                      0.000000
# max       31.000000        1.000000                     13.000000
#
#        no_of_previous_bookings_not_canceled  avg_price_per_room  \
# count                          36275.000000        36275.000000
# mean                               0.153411          103.423539
# std                                1.754171           35.089424
# min                                0.000000            0.000000
# 25%                                0.000000           80.300000
# 50%                                0.000000           99.450000
# 75%                                0.000000          120.000000
# max                               58.000000          540.000000
#
#        no_of_special_requests
# count            36275.000000
# mean                 0.619655
# std                  0.786236
# min                  0.000000
# 25%                  0.000000
# 50%                  0.000000
# 75%                  1.000000
# max                  5.000000

# %%
# How many unique values per feature
df.nunique().to_frame()
# Out:
#                                           0
# Booking_ID                            36275
# no_of_adults                              5
# no_of_children                            6
# no_of_weekend_nights                      8
# no_of_week_nights                        18
# type_of_meal_plan                         4
# required_car_parking_space                2
# room_type_reserved                        7
# lead_time                               352
# arrival_year                              2
# arrival_month                            12
# arrival_date                             31
# market_segment_type                       5
# repeated_guest                            2
# no_of_previous_cancellations              9
# no_of_previous_bookings_not_canceled     59
# avg_price_per_room                     3930
# no_of_special_requests                    6
# booking_status                            2

# %%
# c) Split into Numeric List and Categorical List
# Split the data into numeric and categorical lists and dataframes
numerics = ['int16','int32','int64','float64']
catDF = df.select_dtypes(exclude=numerics)
numDF = df.select_dtypes(include=numerics)
catDF.head()
numDF.head()
# Out:
#   Booking_ID type_of_meal_plan room_type_reserved market_segment_type  \
# 0   INN00001       Meal Plan 1        Room_Type 1             Offline
# 1   INN00002      Not Selected        Room_Type 1              Online
# 2   INN00003       Meal Plan 1        Room_Type 1              Online
# 3   INN00004       Meal Plan 1        Room_Type 1              Online
# 4   INN00005      Not Selected        Room_Type 1              Online
#
#   booking_status
# 0   Not_Canceled
# 1   Not_Canceled
# 2       Canceled
# 3       Canceled
# 4       Canceled
#    no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0             2               0                     1                  2
# 1             2               0                     2                  3
# 2             1               0                     2                  1
# 3             2               0                     0                  2
# 4             2               0                     1                  1
#
#    required_car_parking_space  lead_time  arrival_year  arrival_month  \
# 0                           0        224          2017             10
# 1                           0          5          2018             11
# 2                           0          1          2018              2
# 3                           0        211          2018              5
# 4                           0         48          2018              4
#
#    arrival_date  repeated_guest  no_of_previous_cancellations  \
# 0             2               0                             0
# 1             6               0                             0
# 2            28               0                             0
# 3            20               0                             0
# 4            11               0                             0
#
#    no_of_previous_bookings_not_canceled  avg_price_per_room  \
# 0                                     0               65.00
# 1                                     0              106.68
# 2                                     0               60.00
# 3                                     0              100.00
# 4                                     0               94.50
#
#    no_of_special_requests
# 0                       0
# 1                       1
# 2                       0
# 3                       0
# 4                       0

# %%
# This is how you merge the datasets back together:
# Merge back into a single df
# preparing the X Variables  (Don't forget ot remove the target!!)
X = pd.concat([catDF,numDF],axis=1)
print(X.shape)
# Out:
# (36275, 19)

# %%
# Basic Data Cleaning
df.columns = df.columns.str.lower().str.replace(' ', '_') # A
 
string_columns = list(df.dtypes[df.dtypes == 'object'].index) # B
 
for col in string_columns:
    df[col] = df[col].str.lower().str.replace(' ', '_') # C

# %%
# MISSING VALUES
df.isna()
df.isna().sum()

# Check for missing values in a single column
# df[df['Description'].isna()]

# List all rows that are missing a value in this field
# df.dropna(subset=['Description'])  

# Drop all rows that are missing a value in this field:
# df.dropna(subset=['Description'], inplace=True)

# b) Missing Values per Sample (Big Holes)


plt.figure(figsize=(15, 8))
sns.set_style('whitegrid')

g = sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
# g = sns.heatmap(df_X.loc[df_X.isnull().sum(1).sort_values(ascending=1).index].isnull(), cbar=False, cmap='viridis')
g.set_xlabel('Column Number')
g.set_ylabel('Sample Number')
# Out:
#        booking_id  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0           False         False           False                 False
# 1           False         False           False                 False
# 2           False         False           False                 False
# 3           False         False           False                 False
# 4           False         False           False                 False
# ...           ...           ...             ...                   ...
# 36270       False         False           False                 False
# 36271       False         False           False                 False
# 36272       False         False           False                 False
# 36273       False         False           False                 False
# 36274       False         False           False                 False
#
#        no_of_week_nights  type_of_meal_plan  required_car_parking_space  \
# 0                  False              False                       False
# 1                  False              False                       False
# 2                  False              False                       False
# 3                  False              False                       False
# 4                  False              False                       False
# ...                  ...                ...                         ...
# 36270              False              False                       False
# 36271              False              False                       False
# 36272              False              False                       False
# 36273              False              False                       False
# 36274              False              False                       False
#
#        room_type_reserved  lead_time  arrival_year  arrival_month  \
# 0                   False      False         False          False
# 1                   False      False         False          False
# 2                   False      False         False          False
# 3                   False      False         False          False
# 4                   False      False         False          False
# ...                   ...        ...           ...            ...
# 36270               False      False         False          False
# 36271               False      False         False          False
# 36272               False      False         False          False
# 36273               False      False         False          False
# 36274               False      False         False          False
#
#        arrival_date  market_segment_type  repeated_guest  \
# 0             False                False           False
# 1             False                False           False
# 2             False                False           False
# 3             False                False           False
# 4             False                False           False
# ...             ...                  ...             ...
# 36270         False                False           False
# 36271         False                False           False
# 36272         False                False           False
# 36273         False                False           False
# 36274         False                False           False
#
#        no_of_previous_cancellations  no_of_previous_bookings_not_canceled  \
# 0                             False                                 False
# 1                             False                                 False
# 2                             False                                 False
# 3                             False                                 False
# 4                             False                                 False
# ...                             ...                                   ...
# 36270                         False                                 False
# 36271                         False                                 False
# 36272                         False                                 False
# 36273                         False                                 False
# 36274                         False                                 False
#
#        avg_price_per_room  no_of_special_requests  booking_status
# 0                   False                   False           False
# 1                   False                   False           False
# 2                   False                   False           False
# 3                   False                   False           False
# 4                   False                   False           False
# ...                   ...                     ...             ...
# 36270               False                   False           False
# 36271               False                   False           False
# 36272               False                   False           False
# 36273               False                   False           False
# 36274               False                   False           False
#
# [36275 rows x 19 columns]
# booking_id                              0
# no_of_adults                            0
# no_of_children                          0
# no_of_weekend_nights                    0
# no_of_week_nights                       0
# type_of_meal_plan                       0
# required_car_parking_space              0
# room_type_reserved                      0
# lead_time                               0
# arrival_year                            0
# arrival_month                           0
# arrival_date                            0
# market_segment_type                     0
# repeated_guest                          0
# no_of_previous_cancellations            0
# no_of_previous_bookings_not_canceled    0
# avg_price_per_room                      0
# no_of_special_requests                  0
# booking_status                          0
# dtype: int64
# Text(0.5, 50.09375, 'Column Number')
# Text(114.0, 0.5, 'Sample Number')

# %%
## Need to find the target column, lets try to find the class of target 
df["booking_status"].value_counts()
# Out:
# not_canceled    24390
# canceled        11885
# Name: booking_status, dtype: int64

# %%
# Checking for Null Values 
df.isnull().sum()
# Out:
# booking_id                              0
# no_of_adults                            0
# no_of_children                          0
# no_of_weekend_nights                    0
# no_of_week_nights                       0
# type_of_meal_plan                       0
# required_car_parking_space              0
# room_type_reserved                      0
# lead_time                               0
# arrival_year                            0
# arrival_month                           0
# arrival_date                            0
# market_segment_type                     0
# repeated_guest                          0
# no_of_previous_cancellations            0
# no_of_previous_bookings_not_canceled    0
# avg_price_per_room                      0
# no_of_special_requests                  0
# booking_status                          0
# dtype: int64

# %%
# drop any col that is more than 15% empty
df = df.dropna(thresh=df.shape[0] * 0.85,axis=1)
df.shape
# Out:
# (36275, 19)

# %%
#  Content Investigation of the Data
# a) Distributions of data in each feature
# Plots the histogram for each numerical feature in a separate subplot
df.hist(bins=25, figsize=(15, 25), layout=(-1, 5), edgecolor="black")
plt.tight_layout();

# %%
# b) Patterns
# Creates mask to identify numerical features with more or less than 10 unique features
cols_continuous = df.select_dtypes(include="number").nunique() >= 10

# Create a new dataframe which only contains the continuous features
df_continuous = df[cols_continuous[cols_continuous].index]
df_continuous.shape

sns.pairplot(df_continuous, height=1.5, plot_kws={"s": 2, "alpha": 0.2});

# %%
# Feature Relationships
# Evaluate but remember to consider multicollinearity

# Computes feature correlation
df_corr = df.corr(method="spearman") # pearson assumes a linear relationship... spearman does not

# Create labels for the correlation matrix
labels = np.where(np.abs(df_corr)>0.75, "S",
                  np.where(np.abs(df_corr)>0.5, "M",
                           np.where(np.abs(df_corr)>0.25, "W", "")))

# Plot correlation matrix
plt.figure(figsize=(15, 15))
sns.heatmap(df_corr, mask=np.eye(len(df_corr)), square=True,
            center=0, annot=labels, fmt='', linewidths=.5,
            cmap="vlag", cbar_kws={"shrink": 0.8});

# %%
df.dtypes
# Out:
# booking_id                               object
# no_of_adults                              int64
# no_of_children                            int64
# no_of_weekend_nights                      int64
# no_of_week_nights                         int64
# type_of_meal_plan                        object
# required_car_parking_space                int64
# room_type_reserved                       object
# lead_time                                 int64
# arrival_year                              int64
# arrival_month                             int64
# arrival_date                              int64
# market_segment_type                      object
# repeated_guest                            int64
# no_of_previous_cancellations              int64
# no_of_previous_bookings_not_canceled      int64
# avg_price_per_room                      float64
# no_of_special_requests                    int64
# booking_status                           object
# dtype: object

# %%
# Preprocessing - go through all cat cols and validate against the data dictionary
print('booking_id ' + str(sorted(df['booking_id'].unique())))
# meal_plan
print('type_of_meal_plan  ' + str(sorted(df['type_of_meal_plan'].unique())))
# Out:
# booking_id ['inn00001', 'inn00002', 'inn00003', 'inn00004', 'inn00005', 'inn00006', 'inn00007', 'inn00008', 'inn00009', 'inn00010', 'inn00011', 'inn00012', 'inn00013', 'inn00014', 'inn00015', 'inn00016', 'inn00017', 'inn00018', 'inn00019', 'inn00020', 'inn00021', 'inn00022', 'inn00023', 'inn00024', 'inn00025', 'inn00026', 'inn00027', 'inn00028', 'inn00029', 'inn00030', 'inn00031', 'inn00032', 'inn00033', 'inn00034', 'inn00035', 'inn00036', 'inn00037', 'inn00038', 'inn00039', 'inn00040', 'inn00041', 'inn00042', 'inn00043', 'inn00044', 'inn00045', 'inn00046', 'inn00047', 'inn00048', 'inn00049', 'inn00050', 'inn00051', 'inn00052', 'inn00053', 'inn00054', 'inn00055', 'inn00056', 'inn00057', 'inn00058', 'inn00059', 'inn00060', 'inn00061', 'inn00062', 'inn00063', 'inn00064', 'inn00065', 'inn00066', 'inn00067', 'inn00068', 'inn00069', 'inn00070', 'inn00071', 'inn00072', 'inn00073', 'inn00074', 'inn00075', 'inn00076', 'inn00077', 'inn00078', 'inn00079', 'inn00080', 'inn00081', 'inn00082', 'inn00083', 'inn00084', 'inn00085', 'inn00086', 'inn00087', 'inn00088', 'inn00089', 'inn00090', 'inn00091', 'inn00092', 'inn00093', 'inn00094', 'inn00095', 'inn00096', 'inn00097', 'inn00098', 'inn00099', 'inn00100', 'inn00101', 'inn00102', 'inn00103', 'inn00104', 'inn00105', 'inn00106', 'inn00107', 'inn00108', 'inn00109', 'inn00110', 'inn00111', 'inn00112', 'inn00113', 'inn00114', 'inn00115', 'inn00116', 'inn00117', 'inn00118', 'inn00119', 'inn00120', 'inn00121', 'inn00122', 'inn00123', 'inn00124', 'inn00125', 'inn00126', 'inn00127', 'inn00128', 'inn00129', 'inn00130', 'inn00131', 'inn00132', 'inn00133', 'inn00134', 'inn00135', 'inn00136', 'inn00137', 'inn00138', 'inn00139', 'inn00140', 'inn00141', 'inn00142', 'inn00143', 'inn00144', 'inn00145', 'inn00146', 'inn00147', 'inn00148', 'inn00149', 'inn00150', 'inn00151', 'inn00152', 'inn00153', 'inn00154', 'inn00155', 'inn00156', 'inn00157', 'inn00158', 'inn00159', 'inn00160', 'inn00161', 'inn00162', 'inn00163', 'inn00164', 'inn00165', 'inn00166', 'inn00167', 'inn00168', 'inn00169', 'inn00170', 'inn00171', 'inn00172', 'inn00173', 'inn00174', 'inn00175', 'inn00176', 'inn00177', 'inn00178', 'inn00179', 'inn00180', 'inn00181', 'inn00182', 'inn00183', 'inn00184', 'inn00185', 'inn00186', 'inn00187', 'inn00188', 'inn00189', 'inn00190', 'inn00191', 'inn00192', 'inn00193', 'inn00194', 'inn00195', 'inn00196', 'inn00197', 'inn00198', 'inn00199', 'inn00200', 'inn00201', 'inn00202', 'inn00203', 'inn00204', 'inn00205', 'inn00206', 'inn00207', 'inn00208', 'inn00209', 'inn00210', 'inn00211', 'inn00212', 'inn00213', 'inn00214', 'inn00215', 'inn00216', 'inn00217', 'inn00218', 'inn00219', 'inn00220', 'inn00221', 'inn00222', 'inn00223', 'inn00224', 'inn00225', 'inn00226', 'inn00227', 'inn00228', 'inn00229', 'inn00230', 'inn00231', 'inn00232', 'inn00233', 'inn00234', 'inn00235', 'inn00236', 'inn00237', 'inn00238', 'inn00239', 'inn00240', 'inn00241', 'inn00242', 'inn00243', 'inn00244', 'inn00245', 'inn00246', 'inn00247', 'inn00248', 'inn00249', 'inn00250', 'inn00251', 'inn00252', 'inn00253', 'inn00254', 'inn00255', 'inn00256', 'inn00257', 'inn00258', 'inn00259', 'inn00260', 'inn00261', 'inn00262', 'inn00263', 'inn00264', 'inn00265', 'inn00266', 'inn00267', 'inn00268', 'inn00269', 'inn00270', 'inn00271', 'inn00272', 'inn00273', 'inn00274', 'inn00275', 'inn00276', 'inn00277', 'inn00278', 'inn00279', 'inn00280', 'inn00281', 'inn00282', 'inn00283', 'inn00284', 'inn00285', 'inn00286', 'inn00287', 'inn00288', 'inn00289', 'inn00290', 'inn00291', 'inn00292', 'inn00293', 'inn00294', 'inn00295', 'inn00296', 'inn00297', 'inn00298', 'inn00299', 'inn00300', 'inn00301', 'inn00302', 'inn00303', 'inn00304', 'inn00305', 'inn00306', 'inn00307', 'inn00308', 'inn00309', 'inn00310', 'inn00311', 'inn00312', 'inn00313', 'inn00314', 'inn00315', 'inn00316', 'inn00317', 'inn00318', 'inn00319', 'inn00320', 'inn00321', 'inn00322', 'inn00323', 'inn00324', 'inn00325', 'inn00326', 'inn00327', 'inn00328', 'inn00329', 'inn00330', 'inn00331', 'inn00332', 'inn ...
# type_of_meal_plan  ['meal_plan_1', 'meal_plan_2', 'meal_plan_3', 'not_selected']

# %%
# room_type_reserved 
print('room_type_reserved  ' + str(sorted(df['room_type_reserved'].unique())))
# Out:
# room_type_reserved  ['room_type_1', 'room_type_2', 'room_type_3', 'room_type_4', 'room_type_5', 'room_type_6', 'room_type_7']

# %%
#market_segment_type
print('market_segment_type  ' + str(sorted(df['market_segment_type'].unique())))
# Out:
# market_segment_type  ['aviation', 'complementary', 'corporate', 'offline', 'online']

# %%
# Univariate Analysis - Analyze 1 variable at a time
# This analysis is restricted to cat cols ... 

sns.countplot(x="room_type_reserved", data=df)
# Out:
# <AxesSubplot:xlabel='room_type_reserved', ylabel='count'>

# %%
# Univariate Analysis - Analyze 1 variable at a time
# This analysis is restricted to cat cols ... 

sns.countplot(x="market_segment_type", data=df)
# Out:
# <AxesSubplot:xlabel='market_segment_type', ylabel='count'>

# %%
# Univariate Analysis - Analyze 1 variable at a time
# This analysis is restricted to cat cols ... 

sns.countplot(x="type_of_meal_plan", data=df)
# Out:
# <AxesSubplot:xlabel='type_of_meal_plan', ylabel='count'>

# %%
df['booking_status'].value_counts()
# Out:
# not_canceled    24390
# canceled        11885
# Name: booking_status, dtype: int64

# %%
# Correlation
sns.set(rc={'figure.figsize':(30,10)})
sns.set_context("talk", font_scale=0.7)

# %%
sns.heatmap(df.iloc[:,1:].corr(method='spearman'), cmap='rainbow_r', annot=True)
# Out:
# <AxesSubplot:>

# %%
# Replace with your target variable --- df.YOUR_TARGET_VARIABLE  
# Look for major data imbalances
# Also replace your X label
# REPLACE YOUR TARGET VARIABLE
#plt.figure(figsize=(6, 4))

#sns.histplot(df.target, bins=40, color='black', alpha=1)
#plt.ylabel('sex')
#plt.xlabel('target')
#plt.show()

col = 0
row = 0

fig, ax = plt.subplots(2, 2, figsize=(10, 10))

for column in ["lead_time", "arrival_date", "arrival_month", "avg_price_per_room"]:
    sns.kdeplot(
        data=df, x=column, ax=ax[row, col], hue="booking_status", shade=True
    ).set(title=f"Variable `{column}`")

    col += 1
    if col > 1:
        row += 1
        col = 0
# Out:
# [Text(0.5, 1.0, 'Variable `lead_time`')]
# [Text(0.5, 1.0, 'Variable `arrival_date`')]
# [Text(0.5, 1.0, 'Variable `arrival_month`')]
# [Text(0.5, 1.0, 'Variable `avg_price_per_room`')]

# %%
# Correlation
sns.set(rc={'figure.figsize':(30,10)})
sns.set_context("talk", font_scale=0.7)

# %%
# Split the data into test, train, validation sets... 80/20
from sklearn.model_selection import train_test_split
# This gives the 80/20 train test split
df_train_full, df_test = train_test_split(df, test_size=0.2, random_state=11)

len(df_train_full), len(df_test)
# Replace nulls with 0's - these are pandas dataframes
df_train_full = df_train_full.fillna(0)

df_test = df_test.fillna(0)
len(df_train_full),len(df_test)
# Out:
# (29020, 7255)
# (29020, 7255)

# %%
#Split the y out into train/test/splits... these are numpy ndarrays ... msrp is your target variables
# Replace with your target variable!!!  
y_train = (df_train_full.booking_status).values
y_test = (df_test.booking_status).values
del df_train_full['booking_status']
del df_test['booking_status']

# %%
len(y_train),len(y_test)
# Out:
# (29020, 7255)

# %%
# Convert these data frames into a LIST of DICTIONARIES (each element in the list is a dictionary (the record))
# IF YOU HAVE CAT values... we need to encode them... pandas get dummies OR dictionary vectorizor OR several other examples... allow us to encode
# this example will work with ANY cat data.
dict_train = df_train_full.to_dict(orient='records')
dict_test = df_test.to_dict(orient='records')

# %%
# Convert the LIST OF DICTIONARIES into a Feature Matrix (does all of the encoding)
from sklearn.feature_extraction import DictVectorizer
 
dv = DictVectorizer(sparse=False)
 
X_train = dv.fit_transform(dict_train)
X_test = dv.transform(dict_test)
features = dv.feature_names_  #Features as they exist in the Vectorized Dictionary (this is an ndarray)

# %%
X_test.shape
# Out:
# (7255, 29050)

# %%
# Compare Algorithms with the Algorithm Harness
# https://scikit-learn.org/stable/supervised_learning.html#supervised-learning
from sklearn.metrics import roc_auc_score
from time import time
from sklearn.metrics import explained_variance_score,mean_absolute_error,r2_score
from pandas import read_csv
from matplotlib import pyplot
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
#from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
#from sklearn.naive_bayes import GaussianNB
#from sklearn.svm import SVC
models = []
models.append(('LR', LogisticRegression(solver='liblinear')))
#models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
#models.append(('NB', GaussianNB()))
#models.append(('SVM', SVC(gamma='auto')))
# evaluate each model in turn
results = []
names = []
# scoring = 'roc_auc'
scoring = 'accuracy'
# you can also use other metrics to score your models: https://iqcode.com/code/python/sklearn-cross-val-score-scoring-options
for name, model in models:
    start = time()
    kfold = KFold(n_splits=10, random_state=7, shuffle=True)
    model.fit(X_train, y_train)
    train_time = time() - start
    cv_results = cross_val_score(model, X_train, y_train, cv=kfold, scoring=scoring)
    predict_time = time()-start 
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    #y_pred = model.predict_proba(X_train)[:, 1]
    #auc = roc_auc_score(y_train, y_pred)
    print(msg)
    print("Score for each of the 10 K-fold tests: ",cv_results)
    print(model)
    print("\tTraining time: %0.3fs" % train_time)
    print("\tPrediction time: %0.3fs" % predict_time)
    #y_pred = model.predict(X_test)
    #print("\tExplained variance:", explained_variance_score(y_test, y_pred))
    print()
    
    
    
# boxplot algorithm comparison
fig = pyplot.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
pyplot.boxplot(results)
ax.set_xticklabels(names)
pyplot.show()
# Out:
# LogisticRegression(solver='liblinear')
# LR: 0.798966 (0.007969)
# Score for each of the 10 K-fold tests:  [0.7911785  0.78911096 0.78842178 0.80323915 0.79634735 0.80702963
#  0.7946244  0.81357684 0.80082702 0.80530669]
# LogisticRegression(solver='liblinear')
# 	Training time: 6.797s
# 	Prediction time: 71.466s
# KNeighborsClassifier()
# KNN: 0.807650 (0.005463)
# Score for each of the 10 K-fold tests:  [0.81185389 0.80117161 0.81082012 0.81288766 0.79531358 0.80702963
#  0.80737422 0.81426602 0.80634045 0.80944176]
# KNeighborsClassifier()
# 	Training time: 0.354s
# 	Prediction time: 1666.501s
# DecisionTreeClassifier()
# CART: 0.880186 (0.005531)
# Score for each of the 10 K-fold tests:  [0.87284631 0.87388008 0.88077188 0.88421778 0.87250172 0.8904204
#  0.87939352 0.88077188 0.88146106 0.88559614]
# DecisionTreeClassifier()
# 	Training time: 54.336s
# 	Prediction time: 448.753s
# Text(0.5, 0.98, 'Algorithm Comparison')
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f605c00a9a0>,
#   <matplotlib.lines.Line2D at 0x7f605cdf6130>,
#   <matplotlib.lines.Line2D at 0x7f605d252cd0>,
#   <matplotlib.lines.Line2D at 0x7f605be3cb50>,
#   <matplotlib.lines.Line2D at 0x7f6057124bb0>,
#   <matplotlib.lines.Line2D at 0x7f6057124e20>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f605bcfb3d0>,
#   <matplotlib.lines.Line2D at 0x7f605bcfb250>,
#   <matplotlib.lines.Line2D at 0x7f605be3c6a0>,
#   <matplotlib.lines.Line2D at 0x7f605be3c2b0>,
#   <matplotlib.lines.Line2D at 0x7f6057124fa0>,
#   <matplotlib.lines.Line2D at 0x7f6057124820>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f605c00ac40>,
#   <matplotlib.lines.Line2D at 0x7f605bcfb7c0>,
#   <matplotlib.lines.Line2D at 0x7f605be3cbb0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f605bcfb8e0>,
#   <matplotlib.lines.Line2D at 0x7f605be3c5b0>,
#   <matplotlib.lines.Line2D at 0x7f6057124610>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f605bcfbe80>,
#   <matplotlib.lines.Line2D at 0x7f605be3cc70>,
#   <matplotlib.lines.Line2D at 0x7f605712fd90>],
#  'means': []}
# [Text(1, 0, 'LR'), Text(2, 0, 'KNN'), Text(3, 0, 'CART')]

# %%
# once you have identified a couple of models... being to drill down and tweak it
# %%timeit -n 1
# if you uncomment %%timeit it will not put lr into memory
# Let's assume that the decision tree is the one we want to explore
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)  # in this step here... you are training the data to the model... ie:  fitting the data to the model
# Out:
# DecisionTreeClassifier()

# %%
# This will give you the list of Hyperparameters of your model
dt.get_params()

# %%
# You have converted the dataframe into a list of dictionaries - validate the headers
type(X_train)
type(dv.feature_names_)
type(dt.feature_importances_)
dv.feature_names_
# Out:
# numpy.ndarray
# list
# numpy.ndarray
# ['arrival_date',
#  'arrival_month',
#  'arrival_year',
#  'avg_price_per_room',
#  'booking_id=inn00001',
#  'booking_id=inn00002',
#  'booking_id=inn00003',
#  'booking_id=inn00004',
#  'booking_id=inn00005',
#  'booking_id=inn00006',
#  'booking_id=inn00007',
#  'booking_id=inn00008',
#  'booking_id=inn00009',
#  'booking_id=inn00010',
#  'booking_id=inn00011',
#  'booking_id=inn00012',
#  'booking_id=inn00014',
#  'booking_id=inn00015',
#  'booking_id=inn00016',
#  'booking_id=inn00017',
#  'booking_id=inn00018',
#  'booking_id=inn00019',
#  'booking_id=inn00020',
#  'booking_id=inn00021',
#  'booking_id=inn00022',
#  'booking_id=inn00023',
#  'booking_id=inn00024',
#  'booking_id=inn00025',
#  'booking_id=inn00029',
#  'booking_id=inn00030',
#  'booking_id=inn00032',
#  'booking_id=inn00033',
#  'booking_id=inn00034',
#  'booking_id=inn00036',
#  'booking_id=inn00037',
#  'booking_id=inn00039',
#  'booking_id=inn00040',
#  'booking_id=inn00041',
#  'booking_id=inn00042',
#  'booking_id=inn00043',
#  'booking_id=inn00046',
#  'booking_id=inn00047',
#  'booking_id=inn00049',
#  'booking_id=inn00050',
#  'booking_id=inn00051',
#  'booking_id=inn00052',
#  'booking_id=inn00053',
#  'booking_id=inn00055',
#  'booking_id=inn00056',
#  'booking_id=inn00057',
#  'booking_id=inn00059',
#  'booking_id=inn00060',
#  'booking_id=inn00062',
#  'booking_id=inn00063',
#  'booking_id=inn00064',
#  'booking_id=inn00065',
#  'booking_id=inn00070',
#  'booking_id=inn00071',
#  'booking_id=inn00072',
#  'booking_id=inn00073',
#  'booking_id=inn00076',
#  'booking_id=inn00077',
#  'booking_id=inn00078',
#  'booking_id=inn00079',
#  'booking_id=inn00080',
#  'booking_id=inn00081',
#  'booking_id=inn00082',
#  'booking_id=inn00083',
#  'booking_id=inn00085',
#  'booking_id=inn00086',
#  'booking_id=inn00087',
#  'booking_id=inn00088',
#  'booking_id=inn00089',
#  'booking_id=inn00090',
#  'booking_id=inn00092',
#  'booking_id=inn00093',
#  'booking_id=inn00095',
#  'booking_id=inn00097',
#  'booking_id=inn00098',
#  'booking_id=inn00099',
#  'booking_id=inn00100',
#  'booking_id=inn00101',
#  'booking_id=inn00102',
#  'booking_id=inn00105',
#  'booking_id=inn00106',
#  'booking_id=inn00107',
#  'booking_id=inn00108',
#  'booking_id=inn00109',
#  'booking_id=inn00110',
#  'booking_id=inn00111',
#  'booking_id=inn00112',
#  'booking_id=inn00113',
#  'booking_id=inn00115',
#  'booking_id=inn00116',
#  'booking_id=inn00117',
#  'booking_id=inn00118',
#  'booking_id=inn00119',
#  'booking_id=inn00120',
#  'booking_id=inn00122',
#  'booking_id=inn00126',
#  'booking_id=inn00127',
#  'booking_id=inn00128',
#  'booking_id=inn00129',
#  'booking_id=inn00131',
#  'booking_id=inn00132',
#  'booking_id=inn00133',
#  'booking_id=inn00134',
#  'booking_id=inn00135',
#  'booking_id=inn00136',
#  'booking_id=inn00137',
#  'booking_id=inn00138',
#  'booking_id=inn00140',
#  'booking_id=inn00141',
#  'booking_id=inn00142',
#  'booking_id=inn00143',
#  'booking_id=inn00144',
#  'booking_id=inn00145',
#  'booking_id=inn00146',
#  'booking_id=inn00147',
#  'booking_id=inn00148',
#  'booking_id=inn00149',
#  'booking_id=inn00150',
#  'booking_id=inn00151',
#  'booking_id=inn00152',
#  'booking_id=inn00153',
#  'booking_id=inn00154',
#  'booking_id=inn00155',
#  'booking_id=inn00156',
#  'booking_id=inn00157',
#  'booking_id=inn00158',
#  'booking_id=inn00159',
#  'booking_id=inn00160',
#  'booking_id=inn00161',
#  'booking_id=inn00162',
#  'booking_id=inn00163',
#  'booking_id=inn00164',
#  'booking_id=inn00165',
#  'booking_id=inn00166',
#  'booking_id=inn00167',
#  'booking_id=inn00168',
#  'booking_id=inn00170',
#  'booking_id=inn00171',
#  'booking_id=inn00172',
#  'booking_id=inn00173',
#  'booking_id=inn00174',
#  'booking_id=inn00175',
#  'booking_id=inn00176',
#  'booking_id=inn00177',
#  'booking_id=inn00178',
#  'booking_id=inn00179',
#  'booking_id=inn00180',
#  'booking_id=inn00182',
#  'booking_id=inn00183',
#  'booking_id=inn00185',
#  'booking_id=inn00187',
#  'booking_id=inn00189',
#  'booking_id=inn00192',
#  'booking_id=inn00193',
#  'booking_id=inn00194',
#  'booking_id=inn00195',
#  'booking_id=inn00196',
#  'booking_id=inn00197',
#  'booking_id=inn00198',
#  'booking_id=inn00199',
#  'booking_id=inn00201',
#  'booking_id=inn00202',
#  'booking_id=inn00203',
#  'booking_id=inn00204',
#  'booking_id=inn00205',
#  'booking_id=inn00207',
#  'booking_id=inn00208',
#  'booking_id=inn00209',
#  'booking_id=inn00210',
#  'booking_id=inn00212',
#  'booking_id=inn00214',
#  'booking_id=inn00215',
#  'booking_id=inn00216',
#  'booking_id=inn00217',
#  'booking_id=inn00218',
#  'booking_id=inn00219',
#  'booking_id=inn00220',
#  'booking_id=inn00221',
#  'booking_id=inn00222',
#  'booking_id=inn00224',
#  'booking_id=inn00226',
#  'booking_id=inn00227',
#  'booking_id=inn00229',
#  'booking_id=inn00234',
#  'booking_id=inn00235',
#  'booking_id=inn00236',
#  'booking_id=inn00238',
#  'booking_id=inn00239',
#  'booking_id=inn00240',
#  'booking_id=inn00241',
#  'booking_id=inn00242',
#  'booking_id=inn00243',
#  'booking_id=inn00244',
#  'booking_id=inn00245',
#  'booking_id=inn00246',
#  'booking_id=inn00247',
#  'booking_id=inn00248',
#  'booking_id=inn00249',
#  'booking_id=inn00250',
#  'booking_id=inn00251',
#  'booking_id=inn00252',
#  'booking_id=inn00253',
#  'booking_id=inn00254',
#  'booking_id=inn00256',
#  'booking_id=inn00257',
#  'booking_id=inn00258',
#  'booking_id=inn00259',
#  'booking_id=inn00260',
#  'booking_id=inn00262',
#  'booking_id=inn00263',
#  'booking_id=inn00264',
#  'booking_id=inn00266',
#  'booking_id=inn00267',
#  'booking_id=inn00268',
#  'booking_id=inn00269',
#  'booking_id=inn00271',
#  'booking_id=inn00272',
#  'booking_id=inn00273',
#  'booking_id=inn00277',
#  'booking_id=inn00278',
#  'booking_id=inn00280',
#  'booking_id=inn00281',
#  'booking_id=inn00283',
#  'booking_id=inn00284',
#  'booking_id=inn00285',
#  'booking_id=inn00286',
#  'booking_id=inn00287',
#  'booking_id=inn00288',
#  'booking_id=inn00291',
#  'booking_id=inn00292',
#  'booking_id=inn00293',
#  'booking_id=inn00294',
#  'booking_id=inn00296',
#  'booking_id=inn00298',
#  'booking_id=inn00300',
#  'booking_id=inn00301',
#  'booking_id=inn00302',
#  'booking_id=inn00303',
#  'booking_id=inn00305',
#  'booking_id=inn00306',
#  'booking_id=inn00307',
#  'booking_id=inn00308',
#  'booking_id=inn00309',
#  'booking_id=inn00311',
#  'booking_id=inn00312',
#  'booking_id=inn00313',
#  'booking_id=inn00314',
#  'booking_id=inn00315',
#  'booking_id=inn00316',
#  'booking_id=inn00319',
#  'booking_id=inn00320',
#  'booking_id=inn00321',
#  'booking_id=inn00322',
#  'booking_id=inn00323',
#  'booking_id=inn00324',
#  'booking_id=inn00325',
#  'booking_id=inn00328',
#  'booking_id=inn00329',
#  'booking_id=inn00330',
#  'booking_id=inn00331',
#  'booking_id=inn00332',
#  'booking_id=inn00333',
#  'booking_id=inn00334',
#  'booking_id=inn00335',
#  'booking_id=inn00337',
#  'booking_id=inn00339',
#  'booking_id=inn00340',
#  'booking_id=inn00341',
#  'booking_id=inn00342',
#  'booking_id=inn00343',
#  'booking_id=inn00345',
#  'booking_id=inn00346',
#  'booking_id=inn00347',
#  'booking_id=inn00350',
#  'booking_id=inn00351',
#  'booking_id=inn00352',
#  'booking_id=inn00353',
#  'booking_id=inn00354',
#  'booking_id=inn00355',
#  'booking_id=inn00356',
#  'booking_id=inn00357',
#  'booking_id=inn00358',
#  'booking_id=inn00359',
#  'booking_id=inn00361',
#  'booking_id=inn00362',
#  'booking_id=inn00363',
#  'booking_id=inn00364',
#  'booking_id=inn00366',
#  'booking_id=inn00367',
#  'booking_id=inn00368',
#  'booking_id=inn00370',
#  'booking_id=inn00371',
#  'booking_id=inn00372',
#  'booking_id=inn00373',
#  'booking_id=inn00374',
#  'booking_id=inn00375',
#  'booking_id=inn00376',
#  'booking_id=inn00377',
#  'booking_id=inn00378',
#  'booking_id=inn00379',
#  'booking_id=inn00380',
#  'booking_id=inn00381',
#  'booking_id=inn00382',
#  'booking_id=inn00383',
#  'booking_id=inn00386',
#  'booking_id=inn00387',
#  'booking_id=inn00388',
#  'booking_id=inn00390',
#  'booking_id=inn00394',
#  'booking_id=inn00395',
#  'booking_id=inn00396',
#  'booking_id=inn00397',
#  'booking_id=inn00398',
#  'booking_id=inn00399',
#  'booking_id=inn00400',
#  'booking_id=inn00401',
#  'booking_id=inn00402',
#  'booking_id=inn00403',
#  'booking_id=inn00404',
#  'booking_id=inn00405',
#  'booking_id=inn00408',
#  'booking_id=inn00410',
#  'booking_id=inn00412',
#  'booking_id=inn00413',
#  'booking_id=inn00414',
#  'booking_id=inn00415',
#  'booking_id=inn00416',
#  'booking_id=inn00417',
#  'booking_id=inn00418',
#  'booking_id=inn00420',
#  'booking_id=inn00422',
#  'booking_id=inn00423',
#  'booking_id=inn00424',
#  'booking_id=inn00425',
#  'booking_id=inn00426',
#  'booking_id=inn00428',
#  'booking_id=inn00429',
#  'booking_id=inn00430',
#  'booking_id=inn00431',
#  'booking_id=inn00432',
#  'booking_id=inn00434',
#  'booking_id=inn00435',
#  'booking_id=inn00436',
#  'booking_id=inn00437',
#  'booking_id=inn00438',
#  'booking_id=inn00439',
#  'booking_id=inn00440',
#  'booking_id=inn00441',
#  'booking_id=inn00442',
#  'booking_id=inn00444',
#  'booking_id=inn00446',
#  'booking_id=inn00447',
#  'booking_id=inn00448',
#  'booking_id=inn00449',
#  'booking_id=inn00450',
#  'booking_id=inn00451',
#  'booking_id=inn00453',
#  'booking_id=inn00455',
#  'booking_id=inn00456',
#  'booking_id=inn00457',
#  'booking_id=inn00459',
#  'booking_id=inn00460',
#  'booking_id=inn00461',
#  'booking_id=inn00462',
#  'booking_id=inn00463',
#  'booking_id=inn00464',
#  'booking_id=inn00465',
#  'booking_id=inn00466',
#  'booking_id=inn00467',
#  'booking_id=inn00468',
#  'booking_id=inn00469',
#  'booking_id=inn00470',
#  'booking_id=inn00471',
#  'booking_id=inn00472',
#  'booking_id=inn00473',
#  'booking_id=inn00474',
#  'booking_id=inn00475',
#  'booking_id=inn00476',
#  'booking_id=inn00477',
#  'booking_id=inn00478',
#  'booking_id=inn00479',
#  'booking_id=inn00480',
#  'booking_id=inn00481',
#  'booking_id=inn00482',
#  'booking_id=inn00483',
#  'booking_id=inn00484',
#  'booking_id=inn00486',
#  'booking_id=inn00487',
#  'booking_id=inn00488',
#  'booking_id=inn00489',
#  'booking_id=inn00490',
#  'booking_id=inn00491',
#  'booking_id=inn00492',
#  'booking_id=inn00493',
#  'booking_id=inn00494',
#  'booking_id=inn00495',
#  'booking_id=inn00496',
#  'booking_id=inn00497',
#  'booking_id=inn00498',
#  'booking_id=inn00499',
#  'booking_id=inn00500',
#  'booking_id=inn00501',
#  'booking_id=inn00502',
#  'booking_id=inn00505',
#  'booking_id=inn00507',
#  'booking_id=inn00508',
#  'booking_id=inn00509',
#  'booking_id=inn00510',
#  'booking_id=inn00512',
#  'booking_id=inn00513',
#  'booking_id=inn00516',
#  'booking_id=inn00517',
#  'booking_id=inn00518',
#  'booking_id=inn00519',
#  'booking_id=inn00520',
#  'booking_id=inn00521',
#  'booking_id=inn00522',
#  'booking_id=inn00523',
#  'booking_id=inn00524',
#  'booking_id=inn00526',
#  'booking_id=inn00527',
#  'booking_id=inn00528',
#  'booking_id=inn00529',
#  'booking_id=inn00530',
#  'booking_id=inn00531',
#  'booking_id=inn00532',
#  'booking_id=inn00533',
#  'booking_id=inn00536',
#  'booking_id=inn00537',
#  'booking_id=inn00538',
#  'booking_id=inn00539',
#  'booking_id=inn00540',
#  'booking_id=inn00541',
#  'booking_id=inn00542',
#  'booking_id=inn00543',
#  'booking_id=inn00544',
#  'booking_id=inn00545',
#  'booking_id=inn00547',
#  'booking_id=inn00548',
#  'booking_id=inn00549',
#  'booking_id=inn00551',
#  'booking_id=inn00555',
#  'booking_id=inn00556',
#  'booking_id=inn00557',
#  'booking_id=inn00558',
#  'booking_id=inn00559',
#  'booking_id=inn00560',
#  'booking_id=inn00561',
#  'booking_id=inn00562',
#  'booking_id=inn00563',
#  'booking_id=inn00564',
#  'booking_id=inn00565',
#  'booking_id=inn00567',
#  'booking_id=inn00570',
#  'booking_id=inn00572',
#  'booking_id=inn00573',
#  'booking_id=inn00574',
#  'booking_id=inn00575',
#  'booking_id=inn00576',
#  'booking_id=inn00577',
#  'booking_id=inn00578',
#  'booking_id=inn00580',
#  'booking_id=inn00581',
#  'booking_id=inn00582',
#  'booking_id=inn00583',
#  'booking_id=inn00585',
#  'booking_id=inn00586',
#  'booking_id=inn00587',
#  'booking_id=inn00588',
#  'booking_id=inn00589',
#  'booking_id=inn00590',
#  'booking_id=inn00591',
#  'booking_id=inn00592',
#  'booking_id=inn00593',
#  'booking_id=inn00594',
#  'booking_id=inn00595',
#  'booking_id=inn00596',
#  'booking_id=inn00597',
#  'booking_id=inn00598',
#  'booking_id=inn00599',
#  'booking_id=inn00600',
#  'booking_id=inn00602',
#  'booking_id=inn00603',
#  'booking_id=inn00606',
#  'booking_id=inn00607',
#  'booking_id=inn00608',
#  'booking_id=inn00609',
#  'booking_id=inn00610',
#  'booking_id=inn00611',
#  'booking_id=inn00612',
#  'booking_id=inn00613',
#  'booking_id=inn00614',
#  'booking_id=inn00615',
#  'booking_id=inn00616',
#  'booking_id=inn00618',
#  'booking_id=inn00619',
#  'booking_id=inn00622',
#  'booking_id=inn00623',
#  'booking_id=inn00625',
#  'booking_id=inn00626',
#  'booking_id=inn00627',
#  'booking_id=inn00629',
#  'booking_id=inn00631',
#  'booking_id=inn00632',
#  'booking_id=inn00633',
#  'booking_id=inn00634',
#  'booking_id=inn00636',
#  'booking_id=inn00638',
#  'booking_id=inn00639',
#  'booking_id=inn00641',
#  'booking_id=inn00642',
#  'booking_id=inn00643',
#  'booking_id=inn00645',
#  'booking_id=inn00646',
#  'booking_id=inn00647',
#  'booking_id=inn00648',
#  'booking_id=inn00649',
#  'booking_id=inn00650',
#  'booking_id=inn00651',
#  'booking_id=inn00652',
#  'booking_id=inn00653',
#  'booking_id=inn00654',
#  'booking_id=inn00655',
#  'booking_id=inn00657',
#  'booking_id=inn00658',
#  'booking_id=inn00659',
#  'booking_id=inn00660',
#  'booking_id=inn00661',
#  'booking_id=inn00662',
#  'booking_id=inn00664',
#  'booking_id=inn00665',
#  'booking_id=inn00666',
#  'booking_id=inn00667',
#  'booking_id=inn00668',
#  'booking_id=inn00669',
#  'booking_id=inn00670',
#  'booking_id=inn00671',
#  'booking_id=inn00672',
#  'booking_id=inn00673',
#  'booking_id=inn00674',
#  'booking_id=inn00676',
#  'booking_id=inn00682',
#  'booking_id=inn00683',
#  'booking_id=inn00685',
#  'booking_id=inn00686',
#  'booking_id=inn00687',
#  'booking_id=inn00688',
#  'booking_id=inn00689',
#  'booking_id=inn00690',
#  'booking_id=inn00691',
#  'booking_id=inn00692',
#  'booking_id=inn00693',
#  'booking_id=inn00694',
#  'booking_id=inn00695',
#  'booking_id=inn00696',
#  'booking_id=inn00698',
#  'booking_id=inn00699',
#  'booking_id=inn00700',
#  'booking_id=inn00701',
#  'booking_id=inn00702',
#  'booking_id=inn00703',
#  'booking_id=inn00705',
#  'booking_id=inn00708',
#  'booking_id=inn00709',
#  'booking_id=inn00710',
#  'booking_id=inn00711',
#  'booking_id=inn00712',
#  'booking_id=inn00713',
#  'booking_id=inn00714',
#  'booking_id=inn00715',
#  'booking_id=inn00716',
#  'booking_id=inn00717',
#  'booking_id=inn00718',
#  'booking_id=inn00719',
#  'booking_id=inn00720',
#  'booking_id=inn00721',
#  'booking_id=inn00722',
#  'booking_id=inn00723',
#  'booking_id=inn00724',
#  'booking_id=inn00725',
#  'booking_id=inn00726',
#  'booking_id=inn00727',
#  'booking_id=inn00728',
#  'booking_id=inn00729',
#  'booking_id=inn00730',
#  'booking_id=inn00731',
#  'booking_id=inn00734',
#  'booking_id=inn00737',
#  'booking_id=inn00738',
#  'booking_id=inn00740',
#  'booking_id=inn00741',
#  'booking_id=inn00742',
#  'booking_id=inn00743',
#  'booking_id=inn00744',
#  'booking_id=inn00745',
#  'booking_id=inn00747',
#  'booking_id=inn00748',
#  'booking_id=inn00750',
#  'booking_id=inn00751',
#  'booking_id=inn00754',
#  'booking_id=inn00755',
#  'booking_id=inn00756',
#  'booking_id=inn00757',
#  'booking_id=inn00758',
#  'booking_id=inn00759',
#  'booking_id=inn00760',
#  'booking_id=inn00762',
#  'booking_id=inn00764',
#  'booking_id=inn00765',
#  'booking_id=inn00766',
#  'booking_id=inn00767',
#  'booking_id=inn00769',
#  'booking_id=inn00770',
#  'booking_id=inn00771',
#  'booking_id=inn00772',
#  'booking_id=inn00773',
#  'booking_id=inn00774',
#  'booking_id=inn00775',
#  'booking_id=inn00776',
#  'booking_id=inn00779',
#  'booking_id=inn00780',
#  'booking_id=inn00781',
#  'booking_id=inn00782',
#  'booking_id=inn00783',
#  'booking_id=inn00784',
#  'booking_id=inn00785',
#  'booking_id=inn00786',
#  'booking_id=inn00787',
#  'booking_id=inn00788',
#  'booking_id=inn00789',
#  'booking_id=inn00793',
#  'booking_id=inn00796',
#  'booking_id=inn00797',
#  'booking_id=inn00798',
#  'booking_id=inn00799',
#  'booking_id=inn00800',
#  'booking_id=inn00802',
#  'booking_id=inn00803',
#  'booking_id=inn00805',
#  'booking_id=inn00807',
#  'booking_id=inn00808',
#  'booking_id=inn00809',
#  'booking_id=inn00810',
#  'booking_id=inn00811',
#  'booking_id=inn00812',
#  'booking_id=inn00813',
#  'booking_id=inn00814',
#  'booking_id=inn00816',
#  'booking_id=inn00817',
#  'booking_id=inn00818',
#  'booking_id=inn00819',
#  'booking_id=inn00820',
#  'booking_id=inn00821',
#  'booking_id=inn00822',
#  'booking_id=inn00823',
#  'booking_id=inn00824',
#  'booking_id=inn00826',
#  'booking_id=inn00828',
#  'booking_id=inn00829',
#  'booking_id=inn00830',
#  'booking_id=inn00831',
#  'booking_id=inn00832',
#  'booking_id=inn00835',
#  'booking_id=inn00836',
#  'booking_id=inn00838',
#  'booking_id=inn00839',
#  'booking_id=inn00840',
#  'booking_id=inn00841',
#  'booking_id=inn00842',
#  'booking_id=inn00843',
#  'booking_id=inn00846',
#  'booking_id=inn00847',
#  'booking_id=inn00848',
#  'booking_id=inn00849',
#  'booking_id=inn00850',
#  'booking_id=inn00851',
#  'booking_id=inn00852',
#  'booking_id=inn00853',
#  'booking_id=inn00855',
#  'booking_id=inn00856',
#  'booking_id=inn00857',
#  'booking_id=inn00858',
#  'booking_id=inn00859',
#  'booking_id=inn00860',
#  'booking_id=inn00861',
#  'booking_id=inn00862',
#  'booking_id=inn00863',
#  'booking_id=inn00864',
#  'booking_id=inn00865',
#  'booking_id=inn00866',
#  'booking_id=inn00868',
#  'booking_id=inn00870',
#  'booking_id=inn00871',
#  'booking_id=inn00873',
#  'booking_id=inn00877',
#  'booking_id=inn00878',
#  'booking_id=inn00879',
#  'booking_id=inn00880',
#  'booking_id=inn00881',
#  'booking_id=inn00882',
#  'booking_id=inn00884',
#  'booking_id=inn00886',
#  'booking_id=inn00887',
#  'booking_id=inn00888',
#  'booking_id=inn00889',
#  'booking_id=inn00890',
#  'booking_id=inn00891',
#  'booking_id=inn00895',
#  'booking_id=inn00896',
#  'booking_id=inn00898',
#  'booking_id=inn00899',
#  'booking_id=inn00900',
#  'booking_id=inn00901',
#  'booking_id=inn00902',
#  'booking_id=inn00903',
#  'booking_id=inn00904',
#  'booking_id=inn00905',
#  'booking_id=inn00907',
#  'booking_id=inn00908',
#  'booking_id=inn00909',
#  'booking_id=inn00910',
#  'booking_id=inn00911',
#  'booking_id=inn00912',
#  'booking_id=inn00913',
#  'booking_id=inn00914',
#  'booking_id=inn00915',
#  'booking_id=inn00916',
#  'booking_id=inn00917',
#  'booking_id=inn00919',
#  'booking_id=inn00921',
#  'booking_id=inn00922',
#  'booking_id=inn00923',
#  'booking_id=inn00924',
#  'booking_id=inn00925',
#  'booking_id=inn00926',
#  'booking_id=inn00927',
#  'booking_id=inn00928',
#  'booking_id=inn00932',
#  'booking_id=inn00933',
#  'booking_id=inn00934',
#  'booking_id=inn00935',
#  'booking_id=inn00936',
#  'booking_id=inn00937',
#  'booking_id=inn00938',
#  'booking_id=inn00939',
#  'booking_id=inn00940',
#  'booking_id=inn00942',
#  'booking_id=inn00943',
#  'booking_id=inn00944',
#  'booking_id=inn00945',
#  'booking_id=inn00947',
#  'booking_id=inn00948',
#  'booking_id=inn00949',
#  'booking_id=inn00950',
#  'booking_id=inn00951',
#  'booking_id=inn00952',
#  'booking_id=inn00953',
#  'booking_id=inn00954',
#  'booking_id=inn00955',
#  'booking_id=inn00956',
#  'booking_id=inn00957',
#  'booking_id=inn00958',
#  'booking_id=inn00959',
#  'booking_id=inn00962',
#  'booking_id=inn00964',
#  'booking_id=inn00965',
#  'booking_id=inn00966',
#  'booking_id=inn00967',
#  'booking_id=inn00968',
#  'booking_id=inn00969',
#  'booking_id=inn00971',
#  'booking_id=inn00972',
#  'booking_id=inn00973',
#  'booking_id=inn00974',
#  'booking_id=inn00975',
#  'booking_id=inn00977',
#  'booking_id=inn00978',
#  'booking_id=inn00979',
#  'booking_id=inn00980',
#  'booking_id=inn00981',
#  'booking_id=inn00983',
#  'booking_id=inn00984',
#  'booking_id=inn00985',
#  'booking_id=inn00987',
#  'booking_id=inn00988',
#  'booking_id=inn00989',
#  'booking_id=inn00991',
#  'booking_id=inn00993',
#  'booking_id=inn00994',
#  'booking_id=inn00995',
#  'booking_id=inn00996',
#  'booking_id=inn00997',
#  'booking_id=inn00998',
#  'booking_id=inn01000',
#  'booking_id=inn01002',
#  'booking_id=inn01006',
#  'booking_id=inn01008',
#  'booking_id=inn01010',
#  'booking_id=inn01011',
#  'booking_id=inn01012',
#  'booking_id=inn01013',
#  'booking_id=inn01015',
#  'booking_id=inn01016',
#  'booking_id=inn01017',
#  'booking_id=inn01018',
#  'booking_id=inn01019',
#  'booking_id=inn01020',
#  'booking_id=inn01021',
#  'booking_id=inn01022',
#  'booking_id=inn01023',
#  'booking_id=inn01025',
#  'booking_id=inn01027',
#  'booking_id=inn01028',
#  'booking_id=inn01029',
#  'booking_id=inn01031',
#  'booking_id=inn01033',
#  'booking_id=inn01034',
#  'booking_id=inn01035',
#  'booking_id=inn01037',
#  'booking_id=inn01038',
#  'booking_id=inn01042',
#  'booking_id=inn01043',
#  'booking_id=inn01044',
#  'booking_id=inn01045',
#  'booking_id=inn01046',
#  'booking_id=inn01047',
#  'booking_id=inn01048',
#  'booking_id=inn01050',
#  'booking_id=inn01051',
#  'booking_id=inn01052',
#  'booking_id=inn01053',
#  'booking_id=inn01054',
#  'booking_id=inn01055',
#  'booking_id=inn01056',
#  'booking_id=inn01057',
#  'booking_id=inn01059',
#  'booking_id=inn01060',
#  'booking_id=inn01063',
#  'booking_id=inn01064',
#  'booking_id=inn01065',
#  'booking_id=inn01068',
#  'booking_id=inn01069',
#  'booking_id=inn01071',
#  'booking_id=inn01072',
#  'booking_id=inn01073',
#  'booking_id=inn01074',
#  'booking_id=inn01075',
#  'booking_id=inn01076',
#  'booking_id=inn01077',
#  'booking_id=inn01078',
#  'booking_id=inn01079',
#  'booking_id=inn01080',
#  'booking_id=inn01081',
#  'booking_id=inn01082',
#  'booking_id=inn01083',
#  'booking_id=inn01084',
#  'booking_id=inn01085',
#  'booking_id=inn01086',
#  'booking_id=inn01087',
#  'booking_id=inn01088',
#  'booking_id=inn01089',
#  'booking_id=inn01090',
#  'booking_id=inn01093',
#  'booking_id=inn01094',
#  'booking_id=inn01095',
#  'booking_id=inn01096',
#  'booking_id=inn01097',
#  'booking_id=inn01098',
#  'booking_id=inn01099',
#  'booking_id=inn01100',
#  'booking_id=inn01102',
#  'booking_id=inn01103',
#  'booking_id=inn01104',
#  'booking_id=inn01105',
#  'booking_id=inn01106',
#  'booking_id=inn01107',
#  'booking_id=inn01109',
#  'booking_id=inn01110',
#  'booking_id=inn01111',
#  'booking_id=inn01115',
#  'booking_id=inn01117',
#  'booking_id=inn01118',
#  'booking_id=inn01119',
#  'booking_id=inn01120',
#  'booking_id=inn01121',
#  'booking_id=inn01125',
#  'booking_id=inn01126',
#  'booking_id=inn01127',
#  'booking_id=inn01128',
#  'booking_id=inn01130',
#  'booking_id=inn01131',
#  'booking_id=inn01132',
#  'booking_id=inn01133',
#  'booking_id=inn01135',
#  'booking_id=inn01137',
#  'booking_id=inn01138',
#  'booking_id=inn01139',
#  'booking_id=inn01140',
#  'booking_id=inn01141',
#  'booking_id=inn01142',
#  'booking_id=inn01143',
#  'booking_id=inn01144',
#  'booking_id=inn01145',
#  'booking_id=inn01146',
#  'booking_id=inn01148',
#  'booking_id=inn01149',
#  'booking_id=inn01150',
#  'booking_id=inn01152',
#  'booking_id=inn01154',
#  'booking_id=inn01155',
#  'booking_id=inn01156',
#  'booking_id=inn01157',
#  'booking_id=inn01159',
#  'booking_id=inn01160',
#  'booking_id=inn01161',
#  'booking_id=inn01162',
#  'booking_id=inn01164',
#  'booking_id=inn01165',
#  'booking_id=inn01166',
#  'booking_id=inn01167',
#  'booking_id=inn01168',
#  'booking_id=inn01171',
#  'booking_id=inn01172',
#  'booking_id=inn01173',
#  'booking_id=inn01174',
#  'booking_id=inn01175',
#  'booking_id=inn01176',
#  'booking_id=inn01178',
#  'booking_id=inn01180',
#  'booking_id=inn01181',
#  'booking_id=inn01182',
#  'booking_id=inn01183',
#  'booking_id=inn01184',
#  'booking_id=inn01185',
#  'booking_id=inn01186',
#  'booking_id=inn01187',
#  'booking_id=inn01188',
#  'booking_id=inn01189',
#  'booking_id=inn01190',
#  'booking_id=inn01192',
#  'booking_id=inn01193',
#  'booking_id=inn01194',
#  'booking_id=inn01195',
#  'booking_id=inn01196',
#  'booking_id=inn01197',
#  'booking_id=inn01198',
#  'booking_id=inn01199',
#  'booking_id=inn01200',
#  'booking_id=inn01201',
#  'booking_id=inn01202',
#  'booking_id=inn01203',
#  'booking_id=inn01204',
#  'booking_id=inn01205',
#  'booking_id=inn01206',
#  'booking_id=inn01210',
#  'booking_id=inn01211',
#  'booking_id=inn01212',
#  'booking_id=inn01213',
#  'booking_id=inn01214',
#  'booking_id=inn01215',
#  'booking_id=inn01216',
#  'booking_id=inn01217',
#  'booking_id=inn01218',
#  'booking_id=inn01219',
#  'booking_id=inn01220',
#  'booking_id=inn01221',
#  'booking_id=inn01223',
#  'booking_id=inn01224',
#  'booking_id=inn01225',
#  'booking_id=inn01228',
#  'booking_id=inn01229',
#  'booking_id=inn01231',
#  'booking_id=inn01232',
#  'booking_id=inn01233',
#  'booking_id=inn01234',
#  'booking_id=inn01235',
#  'booking_id=inn01236',
#  'booking_id=inn01237',
#  'booking_id=inn01238',
#  'booking_id=inn01239',
#  'booking_id=inn01240',
#  'booking_id=inn01241',
#  'booking_id=inn01242',
#  'booking_id=inn01243',
#  'booking_id=inn01244',
#  'booking_id=inn01245',
#  'booking_id=inn01246',
#  'booking_id=inn01247',
#  'booking_id=inn01249',
#  'booking_id=inn01250',
#  'booking_id=inn01252',
#  'booking_id=inn01253',
#  'booking_id=inn01254',
#  'booking_id=inn01255',
#  'booking_id=inn01256',
#  'booking_id=inn01257',
#  ...]

# %%
# These are the model properties.  You can call all of these
def get_properties(model):   
  return [i for i in model.__dict__ if i.endswith('_')] 
get_properties(dt)
# Out:
# ['n_features_in_',
#  'n_outputs_',
#  'classes_',
#  'n_classes_',
#  'max_features_',
#  'tree_']

# %%
# Very important.  Once you have a trained model - interegate the coefficients to see WHAT is important
feature_names=dv.feature_names_
# Evaluate the coefficients to learn what the model thinks is important in the predictions.
for i,j in zip(feature_names, dt.feature_importances_): print('%.3f' % j, i)
# Out:
# Streaming output truncated to the last 5000 lines.
# 0.000 booking_id=inn30027
# 0.000 booking_id=inn30028
# 0.000 booking_id=inn30029
# 0.000 booking_id=inn30030
# 0.000 booking_id=inn30031
# 0.000 booking_id=inn30032
# 0.000 booking_id=inn30033
# 0.000 booking_id=inn30034
# 0.000 booking_id=inn30035
# 0.000 booking_id=inn30036
# 0.000 booking_id=inn30037
# 0.000 booking_id=inn30038
# 0.000 booking_id=inn30039
# 0.000 booking_id=inn30040
# 0.000 booking_id=inn30041
# 0.000 booking_id=inn30042
# 0.000 booking_id=inn30045
# 0.000 booking_id=inn30046
# 0.000 booking_id=inn30047
# 0.000 booking_id=inn30048
# 0.000 booking_id=inn30049
# 0.000 booking_id=inn30050
# 0.000 booking_id=inn30051
# 0.000 booking_id=inn30052
# 0.000 booking_id=inn30054
# 0.000 booking_id=inn30055
# 0.000 booking_id=inn30056
# 0.000 booking_id=inn30058
# 0.000 booking_id=inn30060
# 0.000 booking_id=inn30061
# 0.000 booking_id=inn30062
# 0.000 booking_id=inn30063
# 0.000 booking_id=inn30064
# 0.000 booking_id=inn30065
# 0.000 booking_id=inn30066
# 0.000 booking_id=inn30068
# 0.000 booking_id=inn30069
# 0.000 booking_id=inn30070
# 0.000 booking_id=inn30071
# 0.000 booking_id=inn30072
# 0.000 booking_id=inn30073
# 0.000 booking_id=inn30074
# 0.000 booking_id=inn30075
# 0.000 booking_id=inn30076
# 0.000 booking_id=inn30077
# 0.000 booking_id=inn30079
# 0.000 booking_id=inn30080
# 0.000 booking_id=inn30081
# 0.000 booking_id=inn30082
# 0.000 booking_id=inn30084
# 0.000 booking_id=inn30086
# 0.000 booking_id=inn30088
# 0.000 booking_id=inn30089
# 0.000 booking_id=inn30090
# 0.000 booking_id=inn30091
# 0.000 booking_id=inn30092
# 0.000 booking_id=inn30093
# 0.000 booking_id=inn30094
# 0.000 booking_id=inn30095
# 0.000 booking_id=inn30098
# 0.000 booking_id=inn30099
# 0.000 booking_id=inn30101
# 0.000 booking_id=inn30102
# 0.000 booking_id=inn30103
# 0.000 booking_id=inn30104
# 0.000 booking_id=inn30105
# 0.000 booking_id=inn30107
# 0.000 booking_id=inn30108
# 0.000 booking_id=inn30109
# 0.000 booking_id=inn30110
# 0.000 booking_id=inn30111
# 0.000 booking_id=inn30112
# 0.000 booking_id=inn30114
# 0.000 booking_id=inn30115
# 0.000 booking_id=inn30117
# 0.000 booking_id=inn30120
# 0.000 booking_id=inn30121
# 0.000 booking_id=inn30123
# 0.000 booking_id=inn30124
# 0.000 booking_id=inn30125
# 0.000 booking_id=inn30126
# 0.000 booking_id=inn30127
# 0.000 booking_id=inn30128
# 0.000 booking_id=inn30129
# 0.000 booking_id=inn30130
# 0.000 booking_id=inn30131
# 0.000 booking_id=inn30133
# 0.000 booking_id=inn30134
# 0.000 booking_id=inn30137
# 0.000 booking_id=inn30138
# 0.000 booking_id=inn30140
# 0.000 booking_id=inn30141
# 0.000 booking_id=inn30142
# 0.000 booking_id=inn30143
# 0.000 booking_id=inn30144
# 0.000 booking_id=inn30145
# 0.000 booking_id=inn30146
# 0.000 booking_id=inn30147
# 0.000 booking_id=inn30149
# 0.000 booking_id=inn30150
# 0.000 booking_id=inn30151
# 0.000 booking_id=inn30152
# 0.000 booking_id=inn30153
# 0.000 booking_id=inn30154
# 0.000 booking_id=inn30155
# 0.000 booking_id=inn30156
# 0.000 booking_id=inn30157
# 0.000 booking_id=inn30158
# 0.000 booking_id=inn30159
# 0.000 booking_id=inn30160
# 0.000 booking_id=inn30161
# 0.000 booking_id=inn30163
# 0.000 booking_id=inn30164
# 0.000 booking_id=inn30166
# 0.000 booking_id=inn30167
# 0.000 booking_id=inn30168
# 0.000 booking_id=inn30174
# 0.000 booking_id=inn30175
# 0.000 booking_id=inn30176
# 0.000 booking_id=inn30177
# 0.000 booking_id=inn30178
# 0.000 booking_id=inn30179
# 0.000 booking_id=inn30180
# 0.000 booking_id=inn30181
# 0.000 booking_id=inn30184
# 0.000 booking_id=inn30185
# 0.000 booking_id=inn30186
# 0.000 booking_id=inn30188
# 0.000 booking_id=inn30189
# 0.000 booking_id=inn30190
# 0.000 booking_id=inn30191
# 0.000 booking_id=inn30192
# 0.000 booking_id=inn30193
# 0.000 booking_id=inn30194
# 0.000 booking_id=inn30195
# 0.000 booking_id=inn30196
# 0.000 booking_id=inn30197
# 0.000 booking_id=inn30198
# 0.000 booking_id=inn30199
# 0.000 booking_id=inn30200
# 0.000 booking_id=inn30201
# 0.000 booking_id=inn30203
# 0.000 booking_id=inn30204
# 0.000 booking_id=inn30206
# 0.000 booking_id=inn30207
# 0.000 booking_id=inn30208
# 0.000 booking_id=inn30210
# 0.000 booking_id=inn30212
# 0.000 booking_id=inn30213
# 0.000 booking_id=inn30214
# 0.000 booking_id=inn30215
# 0.000 booking_id=inn30216
# 0.000 booking_id=inn30217
# 0.000 booking_id=inn30218
# 0.000 booking_id=inn30220
# 0.000 booking_id=inn30222
# 0.000 booking_id=inn30224
# 0.000 booking_id=inn30225
# 0.000 booking_id=inn30226
# 0.000 booking_id=inn30227
# 0.000 booking_id=inn30228
# 0.000 booking_id=inn30229
# 0.000 booking_id=inn30230
# 0.000 booking_id=inn30231
# 0.000 booking_id=inn30234
# 0.000 booking_id=inn30235
# 0.000 booking_id=inn30236
# 0.000 booking_id=inn30238
# 0.000 booking_id=inn30240
# 0.000 booking_id=inn30242
# 0.000 booking_id=inn30243
# 0.000 booking_id=inn30244
# 0.000 booking_id=inn30245
# 0.000 booking_id=inn30246
# 0.000 booking_id=inn30247
# 0.000 booking_id=inn30248
# 0.000 booking_id=inn30250
# 0.000 booking_id=inn30251
# 0.000 booking_id=inn30252
# 0.000 booking_id=inn30253
# 0.000 booking_id=inn30254
# 0.000 booking_id=inn30255
# 0.000 booking_id=inn30256
# 0.000 booking_id=inn30258
# 0.000 booking_id=inn30259
# 0.000 booking_id=inn30260
# 0.000 booking_id=inn30261
# 0.000 booking_id=inn30262
# 0.000 booking_id=inn30263
# 0.000 booking_id=inn30265
# 0.000 booking_id=inn30266
# 0.000 booking_id=inn30270
# 0.000 booking_id=inn30271
# 0.000 booking_id=inn30273
# 0.000 booking_id=inn30274
# 0.000 booking_id=inn30275
# 0.000 booking_id=inn30276
# 0.000 booking_id=inn30278
# 0.000 booking_id=inn30279
# 0.000 booking_id=inn30280
# 0.000 booking_id=inn30281
# 0.000 booking_id=inn30283
# 0.000 booking_id=inn30284
# 0.000 booking_id=inn30285
# 0.000 booking_id=inn30286
# 0.000 booking_id=inn30287
# 0.000 booking_id=inn30288
# 0.000 booking_id=inn30289
# 0.000 booking_id=inn30290
# 0.000 booking_id=inn30291
# 0.000 booking_id=inn30292
# 0.000 booking_id=inn30293
# 0.000 booking_id=inn30294
# 0.000 booking_id=inn30295
# 0.000 booking_id=inn30296
# 0.000 booking_id=inn30297
# 0.000 booking_id=inn30298
# 0.000 booking_id=inn30299
# 0.000 booking_id=inn30300
# 0.000 booking_id=inn30301
# 0.000 booking_id=inn30302
# 0.000 booking_id=inn30307
# 0.000 booking_id=inn30308
# 0.000 booking_id=inn30311
# 0.000 booking_id=inn30312
# 0.000 booking_id=inn30313
# 0.000 booking_id=inn30314
# 0.000 booking_id=inn30315
# 0.000 booking_id=inn30316
# 0.000 booking_id=inn30317
# 0.000 booking_id=inn30318
# 0.000 booking_id=inn30319
# 0.000 booking_id=inn30320
# 0.000 booking_id=inn30321
# 0.000 booking_id=inn30322
# 0.000 booking_id=inn30323
# 0.000 booking_id=inn30325
# 0.000 booking_id=inn30326
# 0.000 booking_id=inn30327
# 0.000 booking_id=inn30328
# 0.000 booking_id=inn30329
# 0.000 booking_id=inn30331
# 0.000 booking_id=inn30332
# 0.000 booking_id=inn30335
# 0.000 booking_id=inn30336
# 0.000 booking_id=inn30337
# 0.000 booking_id=inn30338
# 0.000 booking_id=inn30339
# 0.000 booking_id=inn30340
# 0.000 booking_id=inn30341
# 0.000 booking_id=inn30342
# 0.000 booking_id=inn30343
# 0.000 booking_id=inn30344
# 0.000 booking_id=inn30345
# 0.000 booking_id=inn30346
# 0.000 booking_id=inn30347
# 0.000 booking_id=inn30348
# 0.000 booking_id=inn30349
# 0.000 booking_id=inn30351
# 0.000 booking_id=inn30352
# 0.000 booking_id=inn30353
# 0.000 booking_id=inn30354
# 0.000 booking_id=inn30355
# 0.000 booking_id=inn30356
# 0.000 booking_id=inn30357
# 0.000 booking_id=inn30358
# 0.000 booking_id=inn30359
# 0.000 booking_id=inn30360
# 0.000 booking_id=inn30361
# 0.000 booking_id=inn30362
# 0.000 booking_id=inn30364
# 0.000 booking_id=inn30365
# 0.000 booking_id=inn30366
# 0.000 booking_id=inn30367
# 0.000 booking_id=inn30370
# 0.000 booking_id=inn30371
# 0.000 booking_id=inn30373
# 0.000 booking_id=inn30374
# 0.000 booking_id=inn30375
# 0.000 booking_id=inn30376
# 0.000 booking_id=inn30377
# 0.000 booking_id=inn30380
# 0.000 booking_id=inn30381
# 0.000 booking_id=inn30382
# 0.000 booking_id=inn30383
# 0.000 booking_id=inn30384
# 0.000 booking_id=inn30385
# 0.000 booking_id=inn30386
# 0.000 booking_id=inn30390
# 0.000 booking_id=inn30391
# 0.000 booking_id=inn30392
# 0.000 booking_id=inn30394
# 0.000 booking_id=inn30395
# 0.000 booking_id=inn30396
# 0.000 booking_id=inn30400
# 0.000 booking_id=inn30401
# 0.000 booking_id=inn30403
# 0.000 booking_id=inn30404
# 0.000 booking_id=inn30405
# 0.000 booking_id=inn30406
# 0.000 booking_id=inn30408
# 0.000 booking_id=inn30410
# 0.000 booking_id=inn30411
# 0.000 booking_id=inn30413
# 0.000 booking_id=inn30414
# 0.000 booking_id=inn30415
# 0.000 booking_id=inn30417
# 0.000 booking_id=inn30418
# 0.000 booking_id=inn30419
# 0.000 booking_id=inn30420
# 0.000 booking_id=inn30421
# 0.000 booking_id=inn30422
# 0.000 booking_id=inn30423
# 0.000 booking_id=inn30424
# 0.000 booking_id=inn30425
# 0.000 booking_id=inn30426
# 0.000 booking_id=inn30427
# 0.000 booking_id=inn30428
# 0.000 booking_id=inn30429
# 0.000 booking_id=inn30430
# 0.000 booking_id=inn30431
# 0.000 booking_id=inn30432
# 0.000 booking_id=inn30433
# 0.000 booking_id=inn30434
# 0.000 booking_id=inn30435
# 0.000 booking_id=inn30437
# 0.000 booking_id=inn30438
# 0.000 booking_id=inn30440
# 0.000 booking_id=inn30442
# 0.000 booking_id=inn30443
# 0.000 booking_id=inn30444
# 0.000 booking_id=inn30445
# 0.000 booking_id=inn30446
# 0.000 booking_id=inn30447
# 0.000 booking_id=inn30448
# 0.000 booking_id=inn30449
# 0.000 booking_id=inn30450
# 0.000 booking_id=inn30451
# 0.000 booking_id=inn30452
# 0.000 booking_id=inn30453
# 0.000 booking_id=inn30454
# 0.000 booking_id=inn30455
# 0.000 booking_id=inn30457
# 0.000 booking_id=inn30458
# 0.000 booking_id=inn30459
# 0.000 booking_id=inn30460
# 0.000 booking_id=inn30462
# 0.000 booking_id=inn30463
# 0.000 booking_id=inn30464
# 0.000 booking_id=inn30465
# 0.000 booking_id=inn30468
# 0.000 booking_id=inn30470
# 0.000 booking_id=inn30471
# 0.000 booking_id=inn30472
# 0.000 booking_id=inn30473
# 0.000 booking_id=inn30474
# 0.000 booking_id=inn30478
# 0.000 booking_id=inn30479
# 0.000 booking_id=inn30480
# 0.000 booking_id=inn30481
# 0.000 booking_id=inn30482
# 0.000 booking_id=inn30483
# 0.000 booking_id=inn30485
# 0.000 booking_id=inn30486
# 0.000 booking_id=inn30488
# 0.000 booking_id=inn30489
# 0.000 booking_id=inn30490
# 0.000 booking_id=inn30492
# 0.000 booking_id=inn30493
# 0.000 booking_id=inn30495
# 0.000 booking_id=inn30499
# 0.000 booking_id=inn30500
# 0.000 booking_id=inn30502
# 0.000 booking_id=inn30503
# 0.000 booking_id=inn30506
# 0.000 booking_id=inn30507
# 0.000 booking_id=inn30508
# 0.000 booking_id=inn30509
# 0.000 booking_id=inn30510
# 0.000 booking_id=inn30512
# 0.000 booking_id=inn30514
# 0.000 booking_id=inn30515
# 0.000 booking_id=inn30516
# 0.000 booking_id=inn30519
# 0.000 booking_id=inn30520
# 0.000 booking_id=inn30521
# 0.000 booking_id=inn30523
# 0.000 booking_id=inn30524
# 0.000 booking_id=inn30525
# 0.000 booking_id=inn30526
# 0.000 booking_id=inn30527
# 0.000 booking_id=inn30528
# 0.000 booking_id=inn30529
# 0.000 booking_id=inn30530
# 0.000 booking_id=inn30533
# 0.000 booking_id=inn30534
# 0.000 booking_id=inn30535
# 0.000 booking_id=inn30536
# 0.000 booking_id=inn30537
# 0.000 booking_id=inn30539
# 0.000 booking_id=inn30540
# 0.000 booking_id=inn30541
# 0.000 booking_id=inn30542
# 0.000 booking_id=inn30543
# 0.000 booking_id=inn30544
# 0.000 booking_id=inn30545
# 0.000 booking_id=inn30546
# 0.000 booking_id=inn30547
# 0.000 booking_id=inn30548
# 0.000 booking_id=inn30550
# 0.000 booking_id=inn30551
# 0.000 booking_id=inn30552
# 0.000 booking_id=inn30553
# 0.000 booking_id=inn30554
# 0.000 booking_id=inn30555
# 0.000 booking_id=inn30556
# 0.000 booking_id=inn30557
# 0.000 booking_id=inn30558
# 0.000 booking_id=inn30559
# 0.000 booking_id=inn30560
# 0.000 booking_id=inn30562
# 0.000 booking_id=inn30563
# 0.000 booking_id=inn30564
# 0.000 booking_id=inn30565
# 0.000 booking_id=inn30566
# 0.000 booking_id=inn30567
# 0.000 booking_id=inn30569
# 0.000 booking_id=inn30570
# 0.000 booking_id=inn30571
# 0.000 booking_id=inn30572
# 0.000 booking_id=inn30574
# 0.000 booking_id=inn30575
# 0.000 booking_id=inn30576
# 0.000 booking_id=inn30578
# 0.000 booking_id=inn30579
# 0.000 booking_id=inn30580
# 0.000 booking_id=inn30582
# 0.000 booking_id=inn30583
# 0.000 booking_id=inn30584
# 0.000 booking_id=inn30585
# 0.000 booking_id=inn30586
# 0.000 booking_id=inn30587
# 0.000 booking_id=inn30589
# 0.000 booking_id=inn30590
# 0.000 booking_id=inn30591
# 0.000 booking_id=inn30592
# 0.000 booking_id=inn30594
# 0.000 booking_id=inn30596
# 0.000 booking_id=inn30597
# 0.000 booking_id=inn30598
# 0.000 booking_id=inn30601
# 0.000 booking_id=inn30602
# 0.000 booking_id=inn30603
# 0.000 booking_id=inn30604
# 0.000 booking_id=inn30605
# 0.000 booking_id=inn30606
# 0.000 booking_id=inn30607
# 0.000 booking_id=inn30608
# 0.000 booking_id=inn30609
# 0.000 booking_id=inn30610
# 0.000 booking_id=inn30611
# 0.000 booking_id=inn30612
# 0.000 booking_id=inn30613
# 0.000 booking_id=inn30614
# 0.000 booking_id=inn30615
# 0.000 booking_id=inn30616
# 0.000 booking_id=inn30617
# 0.000 booking_id=inn30618
# 0.000 booking_id=inn30620
# 0.000 booking_id=inn30621
# 0.000 booking_id=inn30622
# 0.000 booking_id=inn30623
# 0.000 booking_id=inn30624
# 0.000 booking_id=inn30625
# 0.000 booking_id=inn30626
# 0.000 booking_id=inn30627
# 0.000 booking_id=inn30629
# 0.000 booking_id=inn30630
# 0.000 booking_id=inn30631
# 0.000 booking_id=inn30632
# 0.000 booking_id=inn30634
# 0.000 booking_id=inn30635
# 0.000 booking_id=inn30637
# 0.000 booking_id=inn30638
# 0.000 booking_id=inn30641
# 0.000 booking_id=inn30643
# 0.000 booking_id=inn30644
# 0.000 booking_id=inn30645
# 0.000 booking_id=inn30646
# 0.000 booking_id=inn30647
# 0.000 booking_id=inn30649
# 0.000 booking_id=inn30650
# 0.000 booking_id=inn30651
# 0.000 booking_id=inn30652
# 0.000 booking_id=inn30653
# 0.000 booking_id=inn30655
# 0.000 booking_id=inn30656
# 0.000 booking_id=inn30657
# 0.000 booking_id=inn30658
# 0.000 booking_id=inn30659
# 0.000 booking_id=inn30660
# 0.000 booking_id=inn30661
# 0.000 booking_id=inn30663
# 0.000 booking_id=inn30665
# 0.000 booking_id=inn30666
# 0.000 booking_id=inn30668
# 0.000 booking_id=inn30670
# 0.000 booking_id=inn30672
# 0.000 booking_id=inn30674
# 0.000 booking_id=inn30675
# 0.000 booking_id=inn30677
# 0.000 booking_id=inn30678
# 0.000 booking_id=inn30680
# 0.000 booking_id=inn30682
# 0.000 booking_id=inn30683
# 0.000 booking_id=inn30684
# 0.000 booking_id=inn30685
# 0.000 booking_id=inn30686
# 0.000 booking_id=inn30687
# 0.000 booking_id=inn30688
# 0.000 booking_id=inn30690
# 0.000 booking_id=inn30691
# 0.000 booking_id=inn30692
# 0.000 booking_id=inn30694
# 0.000 booking_id=inn30695
# 0.000 booking_id=inn30696
# 0.000 booking_id=inn30697
# 0.000 booking_id=inn30698
# 0.000 booking_id=inn30699
# 0.000 booking_id=inn30702
# 0.000 booking_id=inn30703
# 0.000 booking_id=inn30704
# 0.000 booking_id=inn30705
# 0.000 booking_id=inn30706
# 0.000 booking_id=inn30707
# 0.000 booking_id=inn30708
# 0.000 booking_id=inn30710
# 0.000 booking_id=inn30711
# 0.000 booking_id=inn30712
# 0.000 booking_id=inn30714
# 0.000 booking_id=inn30715
# 0.000 booking_id=inn30718
# 0.000 booking_id=inn30720
# 0.000 booking_id=inn30721
# 0.000 booking_id=inn30722
# 0.000 booking_id=inn30723
# 0.000 booking_id=inn30724
# 0.000 booking_id=inn30725
# 0.000 booking_id=inn30726
# 0.000 booking_id=inn30727
# 0.000 booking_id=inn30728
# 0.000 booking_id=inn30729
# 0.000 booking_id=inn30730
# 0.000 booking_id=inn30731
# 0.000 booking_id=inn30732
# 0.000 booking_id=inn30733
# 0.000 booking_id=inn30734
# 0.000 booking_id=inn30735
# 0.000 booking_id=inn30736
# 0.000 booking_id=inn30737
# 0.000 booking_id=inn30738
# 0.000 booking_id=inn30739
# 0.000 booking_id=inn30740
# 0.000 booking_id=inn30741
# 0.000 booking_id=inn30742
# 0.000 booking_id=inn30743
# 0.000 booking_id=inn30744
# 0.000 booking_id=inn30745
# 0.000 booking_id=inn30746
# 0.000 booking_id=inn30747
# 0.000 booking_id=inn30748
# 0.000 booking_id=inn30749
# 0.000 booking_id=inn30750
# 0.000 booking_id=inn30751
# 0.000 booking_id=inn30752
# 0.000 booking_id=inn30753
# 0.000 booking_id=inn30755
# 0.000 booking_id=inn30756
# 0.000 booking_id=inn30757
# 0.000 booking_id=inn30758
# 0.000 booking_id=inn30759
# 0.000 booking_id=inn30760
# 0.000 booking_id=inn30761
# 0.000 booking_id=inn30763
# 0.000 booking_id=inn30764
# 0.000 booking_id=inn30765
# 0.000 booking_id=inn30766
# 0.000 booking_id=inn30767
# 0.000 booking_id=inn30768
# 0.000 booking_id=inn30769
# 0.000 booking_id=inn30770
# 0.000 booking_id=inn30771
# 0.000 booking_id=inn30772
# 0.000 booking_id=inn30773
# 0.000 booking_id=inn30774
# 0.000 booking_id=inn30777
# 0.000 booking_id=inn30778
# 0.000 booking_id=inn30779
# 0.000 booking_id=inn30780
# 0.000 booking_id=inn30782
# 0.000 booking_id=inn30783
# 0.000 booking_id=inn30784
# 0.000 booking_id=inn30785
# 0.000 booking_id=inn30787
# 0.000 booking_id=inn30788
# 0.000 booking_id=inn30789
# 0.000 booking_id=inn30790
# 0.000 booking_id=inn30791
# 0.000 booking_id=inn30792
# 0.000 booking_id=inn30793
# 0.000 booking_id=inn30794
# 0.000 booking_id=inn30795
# 0.000 booking_id=inn30796
# 0.000 booking_id=inn30797
# 0.000 booking_id=inn30798
# 0.000 booking_id=inn30799
# 0.000 booking_id=inn30801
# 0.000 booking_id=inn30802
# 0.000 booking_id=inn30803
# 0.000 booking_id=inn30805
# 0.000 booking_id=inn30807
# 0.000 booking_id=inn30808
# 0.000 booking_id=inn30810
# 0.000 booking_id=inn30811
# 0.000 booking_id=inn30813
# 0.000 booking_id=inn30814
# 0.000 booking_id=inn30815
# 0.000 booking_id=inn30817
# 0.000 booking_id=inn30819
# 0.000 booking_id=inn30820
# 0.000 booking_id=inn30821
# 0.000 booking_id=inn30823
# 0.000 booking_id=inn30824
# 0.000 booking_id=inn30825
# 0.000 booking_id=inn30826
# 0.000 booking_id=inn30827
# 0.000 booking_id=inn30829
# 0.000 booking_id=inn30830
# 0.000 booking_id=inn30831
# 0.000 booking_id=inn30832
# 0.000 booking_id=inn30833
# 0.000 booking_id=inn30834
# 0.000 booking_id=inn30837
# 0.000 booking_id=inn30838
# 0.000 booking_id=inn30840
# 0.000 booking_id=inn30841
# 0.000 booking_id=inn30842
# 0.000 booking_id=inn30844
# 0.000 booking_id=inn30846
# 0.000 booking_id=inn30847
# 0.000 booking_id=inn30848
# 0.000 booking_id=inn30849
# 0.000 booking_id=inn30850
# 0.000 booking_id=inn30851
# 0.000 booking_id=inn30852
# 0.000 booking_id=inn30853
# 0.000 booking_id=inn30854
# 0.000 booking_id=inn30855
# 0.000 booking_id=inn30856
# 0.000 booking_id=inn30857
# 0.000 booking_id=inn30859
# 0.000 booking_id=inn30860
# 0.000 booking_id=inn30861
# 0.000 booking_id=inn30862
# 0.000 booking_id=inn30863
# 0.000 booking_id=inn30864
# 0.000 booking_id=inn30867
# 0.000 booking_id=inn30868
# 0.000 booking_id=inn30869
# 0.000 booking_id=inn30870
# 0.000 booking_id=inn30871
# 0.000 booking_id=inn30872
# 0.000 booking_id=inn30873
# 0.000 booking_id=inn30874
# 0.000 booking_id=inn30875
# 0.000 booking_id=inn30876
# 0.000 booking_id=inn30877
# 0.000 booking_id=inn30878
# 0.000 booking_id=inn30879
# 0.000 booking_id=inn30880
# 0.000 booking_id=inn30881
# 0.000 booking_id=inn30882
# 0.000 booking_id=inn30883
# 0.000 booking_id=inn30884
# 0.000 booking_id=inn30885
# 0.000 booking_id=inn30887
# 0.000 booking_id=inn30888
# 0.000 booking_id=inn30889
# 0.000 booking_id=inn30890
# 0.000 booking_id=inn30891
# 0.000 booking_id=inn30892
# 0.000 booking_id=inn30894
# 0.000 booking_id=inn30895
# 0.000 booking_id=inn30896
# 0.000 booking_id=inn30898
# 0.000 booking_id=inn30900
# 0.000 booking_id=inn30901
# 0.000 booking_id=inn30903
# 0.000 booking_id=inn30904
# 0.000 booking_id=inn30905
# 0.000 booking_id=inn30906
# 0.000 booking_id=inn30909
# 0.000 booking_id=inn30911
# 0.000 booking_id=inn30912
# 0.000 booking_id=inn30913
# 0.000 booking_id=inn30914
# 0.000 booking_id=inn30915
# 0.000 booking_id=inn30916
# 0.000 booking_id=inn30917
# 0.000 booking_id=inn30918
# 0.000 booking_id=inn30919
# 0.000 booking_id=inn30920
# 0.000 booking_id=inn30921
# 0.000 booking_id=inn30922
# 0.000 booking_id=inn30923
# 0.000 booking_id=inn30924
# 0.000 booking_id=inn30925
# 0.000 booking_id=inn30927
# 0.000 booking_id=inn30928
# 0.000 booking_id=inn30929
# 0.000 booking_id=inn30931
# 0.000 booking_id=inn30934
# 0.000 booking_id=inn30935
# 0.000 booking_id=inn30936
# 0.000 booking_id=inn30937
# 0.000 booking_id=inn30938
# 0.000 booking_id=inn30939
# 0.000 booking_id=inn30940
# 0.000 booking_id=inn30941
# 0.000 booking_id=inn30942
# 0.000 booking_id=inn30943
# 0.000 booking_id=inn30945
# 0.000 booking_id=inn30946
# 0.000 booking_id=inn30947
# 0.000 booking_id=inn30948
# 0.000 booking_id=inn30949
# 0.000 booking_id=inn30950
# 0.000 booking_id=inn30952
# 0.000 booking_id=inn30953
# 0.000 booking_id=inn30954
# 0.000 booking_id=inn30955
# 0.000 booking_id=inn30956
# 0.000 booking_id=inn30957
# 0.000 booking_id=inn30958
# 0.000 booking_id=inn30960
# 0.000 booking_id=inn30961
# 0.000 booking_id=inn30963
# 0.000 booking_id=inn30965
# 0.000 booking_id=inn30967
# 0.000 booking_id=inn30969
# 0.000 booking_id=inn30970
# 0.000 booking_id=inn30972
# 0.000 booking_id=inn30973
# 0.000 booking_id=inn30974
# 0.000 booking_id=inn30975
# 0.000 booking_id=inn30976
# 0.000 booking_id=inn30977
# 0.000 booking_id=inn30978
# 0.000 booking_id=inn30979
# 0.000 booking_id=inn30980
# 0.000 booking_id=inn30982
# 0.000 booking_id=inn30983
# 0.000 booking_id=inn30984
# 0.000 booking_id=inn30985
# 0.000 booking_id=inn30986
# 0.000 booking_id=inn30987
# 0.000 booking_id=inn30988
# 0.000 booking_id=inn30989
# 0.000 booking_id=inn30990
# 0.000 booking_id=inn30991
# 0.000 booking_id=inn30992
# 0.000 booking_id=inn30993
# 0.000 booking_id=inn30995
# 0.000 booking_id=inn30996
# 0.000 booking_id=inn30998
# 0.000 booking_id=inn30999
# 0.000 booking_id=inn31000
# 0.000 booking_id=inn31001
# 0.000 booking_id=inn31002
# 0.000 booking_id=inn31003
# 0.000 booking_id=inn31004
# 0.000 booking_id=inn31005
# 0.000 booking_id=inn31006
# 0.000 booking_id=inn31007
# 0.000 booking_id=inn31008
# 0.000 booking_id=inn31009
# 0.000 booking_id=inn31011
# 0.000 booking_id=inn31012
# 0.000 booking_id=inn31013
# 0.000 booking_id=inn31014
# 0.000 booking_id=inn31015
# 0.000 booking_id=inn31016
# 0.000 booking_id=inn31017
# 0.000 booking_id=inn31018
# 0.000 booking_id=inn31019
# 0.000 booking_id=inn31020
# 0.000 booking_id=inn31022
# 0.000 booking_id=inn31023
# 0.000 booking_id=inn31024
# 0.000 booking_id=inn31025
# 0.000 booking_id=inn31028
# 0.000 booking_id=inn31029
# 0.000 booking_id=inn31030
# 0.000 booking_id=inn31031
# 0.000 booking_id=inn31032
# 0.000 booking_id=inn31033
# 0.000 booking_id=inn31034
# 0.000 booking_id=inn31035
# 0.000 booking_id=inn31036
# 0.000 booking_id=inn31037
# 0.000 booking_id=inn31038
# 0.000 booking_id=inn31039
# 0.000 booking_id=inn31040
# 0.000 booking_id=inn31041
# 0.000 booking_id=inn31043
# 0.000 booking_id=inn31044
# 0.000 booking_id=inn31045
# 0.000 booking_id=inn31046
# 0.000 booking_id=inn31047
# 0.000 booking_id=inn31049
# 0.000 booking_id=inn31050
# 0.000 booking_id=inn31051
# 0.000 booking_id=inn31053
# 0.000 booking_id=inn31055
# 0.000 booking_id=inn31056
# 0.000 booking_id=inn31057
# 0.000 booking_id=inn31058
# 0.000 booking_id=inn31059
# 0.000 booking_id=inn31060
# 0.000 booking_id=inn31061
# 0.000 booking_id=inn31062
# 0.000 booking_id=inn31063
# 0.000 booking_id=inn31064
# 0.000 booking_id=inn31065
# 0.000 booking_id=inn31066
# 0.000 booking_id=inn31068
# 0.000 booking_id=inn31069
# 0.000 booking_id=inn31070
# 0.000 booking_id=inn31072
# 0.000 booking_id=inn31073
# 0.000 booking_id=inn31074
# 0.000 booking_id=inn31077
# 0.000 booking_id=inn31078
# 0.000 booking_id=inn31079
# 0.000 booking_id=inn31080
# 0.000 booking_id=inn31081
# 0.000 booking_id=inn31082
# 0.000 booking_id=inn31083
# 0.000 booking_id=inn31084
# 0.000 booking_id=inn31085
# 0.000 booking_id=inn31086
# 0.000 booking_id=inn31087
# 0.000 booking_id=inn31088
# 0.000 booking_id=inn31090
# 0.000 booking_id=inn31091
# 0.000 booking_id=inn31092
# 0.000 booking_id=inn31093
# 0.000 booking_id=inn31094
# 0.000 booking_id=inn31095
# 0.000 booking_id=inn31097
# 0.000 booking_id=inn31098
# 0.000 booking_id=inn31099
# 0.000 booking_id=inn31100
# 0.000 booking_id=inn31101
# 0.000 booking_id=inn31102
# 0.000 booking_id=inn31103
# 0.000 booking_id=inn31104
# 0.000 booking_id=inn31106
# 0.000 booking_id=inn31108
# 0.000 booking_id=inn31109
# 0.000 booking_id=inn31110
# 0.000 booking_id=inn31111
# 0.000 booking_id=inn31112
# 0.000 booking_id=inn31114
# 0.000 booking_id=inn31115
# 0.000 booking_id=inn31116
# 0.000 booking_id=inn31117
# 0.000 booking_id=inn31118
# 0.000 booking_id=inn31119
# 0.000 booking_id=inn31120
# 0.000 booking_id=inn31121
# 0.000 booking_id=inn31122
# 0.000 booking_id=inn31124
# 0.000 booking_id=inn31125
# 0.000 booking_id=inn31126
# 0.000 booking_id=inn31127
# 0.000 booking_id=inn31128
# 0.000 booking_id=inn31129
# 0.000 booking_id=inn31130
# 0.000 booking_id=inn31131
# 0.000 booking_id=inn31132
# 0.000 booking_id=inn31133
# 0.000 booking_id=inn31134
# 0.000 booking_id=inn31135
# 0.000 booking_id=inn31137
# 0.000 booking_id=inn31138
# 0.000 booking_id=inn31139
# 0.000 booking_id=inn31140
# 0.000 booking_id=inn31142
# 0.000 booking_id=inn31143
# 0.000 booking_id=inn31144
# 0.000 booking_id=inn31145
# 0.000 booking_id=inn31146
# 0.000 booking_id=inn31147
# 0.000 booking_id=inn31148
# 0.000 booking_id=inn31149
# 0.000 booking_id=inn31150
# 0.000 booking_id=inn31151
# 0.000 booking_id=inn31152
# 0.000 booking_id=inn31153
# 0.000 booking_id=inn31156
# 0.000 booking_id=inn31157
# 0.000 booking_id=inn31158
# 0.000 booking_id=inn31159
# 0.000 booking_id=inn31160
# 0.000 booking_id=inn31161
# 0.000 booking_id=inn31162
# 0.000 booking_id=inn31163
# 0.000 booking_id=inn31164
# 0.000 booking_id=inn31165
# 0.000 booking_id=inn31166
# 0.000 booking_id=inn31167
# 0.000 booking_id=inn31168
# 0.000 booking_id=inn31169
# 0.000 booking_id=inn31171
# 0.000 booking_id=inn31173
# 0.000 booking_id=inn31174
# 0.000 booking_id=inn31176
# 0.000 booking_id=inn31177
# 0.000 booking_id=inn31179
# 0.000 booking_id=inn31180
# 0.000 booking_id=inn31182
# 0.000 booking_id=inn31183
# 0.000 booking_id=inn31184
# 0.000 booking_id=inn31185
# 0.000 booking_id=inn31186
# 0.000 booking_id=inn31187
# 0.000 booking_id=inn31188
# 0.000 booking_id=inn31190
# 0.000 booking_id=inn31192
# 0.000 booking_id=inn31193
# 0.000 booking_id=inn31195
# 0.000 booking_id=inn31196
# 0.000 booking_id=inn31197
# 0.000 booking_id=inn31198
# 0.000 booking_id=inn31199
# 0.000 booking_id=inn31200
# 0.000 booking_id=inn31202
# 0.000 booking_id=inn31203
# 0.000 booking_id=inn31204
# 0.000 booking_id=inn31205
# 0.000 booking_id=inn31206
# 0.000 booking_id=inn31207
# 0.000 booking_id=inn31209
# 0.000 booking_id=inn31210
# 0.000 booking_id=inn31211
# 0.000 booking_id=inn31213
# 0.000 booking_id=inn31214
# 0.000 booking_id=inn31215
# 0.000 booking_id=inn31216
# 0.000 booking_id=inn31217
# 0.000 booking_id=inn31218
# 0.000 booking_id=inn31219
# 0.000 booking_id=inn31220
# 0.000 booking_id=inn31221
# 0.000 booking_id=inn31222
# 0.000 booking_id=inn31223
# 0.000 booking_id=inn31224
# 0.000 booking_id=inn31225
# 0.000 booking_id=inn31226
# 0.000 booking_id=inn31227
# 0.000 booking_id=inn31228
# 0.000 booking_id=inn31229
# 0.000 booking_id=inn31230
# 0.000 booking_id=inn31231
# 0.000 booking_id=inn31232
# 0.000 booking_id=inn31233
# 0.000 booking_id=inn31235
# 0.000 booking_id=inn31236
# 0.000 booking_id=inn31237
# 0.000 booking_id=inn31238
# 0.000 booking_id=inn31239
# 0.000 booking_id=inn31240
# 0.000 booking_id=inn31242
# 0.000 booking_id=inn31243
# 0.000 booking_id=inn31244
# 0.000 booking_id=inn31245
# 0.000 booking_id=inn31246
# 0.000 booking_id=inn31248
# 0.000 booking_id=inn31249
# 0.000 booking_id=inn31250
# 0.000 booking_id=inn31251
# 0.000 booking_id=inn31252
# 0.000 booking_id=inn31253
# 0.000 booking_id=inn31254
# 0.000 booking_id=inn31255
# 0.000 booking_id=inn31256
# 0.000 booking_id=inn31257
# 0.000 booking_id=inn31258
# 0.000 booking_id=inn31259
# 0.000 booking_id=inn31260
# 0.000 booking_id=inn31261
# 0.000 booking_id=inn31262
# 0.000 booking_id=inn31263
# 0.000 booking_id=inn31266
# 0.000 booking_id=inn31267
# 0.000 booking_id=inn31268
# 0.000 booking_id=inn31270
# 0.000 booking_id=inn31271
# 0.000 booking_id=inn31272
# 0.000 booking_id=inn31273
# 0.000 booking_id=inn31274
# 0.000 booking_id=inn31275
# 0.000 booking_id=inn31276
# 0.000 booking_id=inn31277
# 0.000 booking_id=inn31278
# 0.000 booking_id=inn31279
# 0.000 booking_id=inn31280
# 0.000 booking_id=inn31283
# 0.000 booking_id=inn31284
# 0.000 booking_id=inn31285
# 0.000 booking_id=inn31286
# 0.000 booking_id=inn31287
# 0.000 booking_id=inn31288
# 0.000 booking_id=inn31291
# 0.000 booking_id=inn31293
# 0.000 booking_id=inn31295
# 0.000 booking_id=inn31296
# 0.000 booking_id=inn31298
# 0.000 booking_id=inn31299
# 0.000 booking_id=inn31300
# 0.000 booking_id=inn31301
# 0.000 booking_id=inn31302
# 0.000 booking_id=inn31303
# 0.000 booking_id=inn31304
# 0.000 booking_id=inn31305
# 0.000 booking_id=inn31306
# 0.000 booking_id=inn31307
# 0.000 booking_id=inn31308
# 0.000 booking_id=inn31309
# 0.000 booking_id=inn31310
# 0.000 booking_id=inn31311
# 0.000 booking_id=inn31312
# 0.000 booking_id=inn31313
# 0.000 booking_id=inn31315
# 0.000 booking_id=inn31317
# 0.000 booking_id=inn31318
# 0.000 booking_id=inn31319
# 0.000 booking_id=inn31320
# 0.000 booking_id=inn31321
# 0.000 booking_id=inn31322
# 0.000 booking_id=inn31323
# 0.000 booking_id=inn31326
# 0.000 booking_id=inn31327
# 0.000 booking_id=inn31328
# 0.000 booking_id=inn31329
# 0.000 booking_id=inn31331
# 0.000 booking_id=inn31334
# 0.000 booking_id=inn31335
# 0.000 booking_id=inn31338
# 0.000 booking_id=inn31339
# 0.000 booking_id=inn31340
# 0.000 booking_id=inn31341
# 0.000 booking_id=inn31342
# 0.000 booking_id=inn31343
# 0.000 booking_id=inn31344
# 0.000 booking_id=inn31345
# 0.000 booking_id=inn31346
# 0.000 booking_id=inn31347
# 0.000 booking_id=inn31348
# 0.000 booking_id=inn31349
# 0.000 booking_id=inn31350
# 0.000 booking_id=inn31351
# 0.000 booking_id=inn31354
# 0.000 booking_id=inn31355
# 0.000 booking_id=inn31356
# 0.000 booking_id=inn31357
# 0.000 booking_id=inn31358
# 0.000 booking_id=inn31359
# 0.000 booking_id=inn31362
# 0.000 booking_id=inn31363
# 0.000 booking_id=inn31364
# 0.000 booking_id=inn31365
# 0.000 booking_id=inn31366
# 0.000 booking_id=inn31367
# 0.000 booking_id=inn31368
# 0.000 booking_id=inn31369
# 0.000 booking_id=inn31370
# 0.000 booking_id=inn31372
# 0.000 booking_id=inn31373
# 0.000 booking_id=inn31374
# 0.000 booking_id=inn31375
# 0.000 booking_id=inn31376
# 0.000 booking_id=inn31378
# 0.000 booking_id=inn31379
# 0.000 booking_id=inn31380
# 0.000 booking_id=inn31381
# 0.000 booking_id=inn31382
# 0.000 booking_id=inn31383
# 0.000 booking_id=inn31385
# 0.000 booking_id=inn31386
# 0.000 booking_id=inn31387
# 0.000 booking_id=inn31388
# 0.000 booking_id=inn31390
# 0.000 booking_id=inn31391
# 0.000 booking_id=inn31392
# 0.000 booking_id=inn31393
# 0.000 booking_id=inn31394
# 0.000 booking_id=inn31397
# 0.000 booking_id=inn31398
# 0.000 booking_id=inn31399
# 0.000 booking_id=inn31400
# 0.000 booking_id=inn31401
# 0.000 booking_id=inn31402
# 0.000 booking_id=inn31403
# 0.000 booking_id=inn31404
# 0.000 booking_id=inn31405
# 0.000 booking_id=inn31406
# 0.000 booking_id=inn31407
# 0.000 booking_id=inn31408
# 0.000 booking_id=inn31409
# 0.000 booking_id=inn31410
# 0.000 booking_id=inn31412
# 0.000 booking_id=inn31413
# 0.000 booking_id=inn31414
# 0.000 booking_id=inn31417
# 0.000 booking_id=inn31418
# 0.000 booking_id=inn31419
# 0.000 booking_id=inn31420
# 0.000 booking_id=inn31421
# 0.000 booking_id=inn31422
# 0.000 booking_id=inn31423
# 0.000 booking_id=inn31424
# 0.000 booking_id=inn31425
# 0.000 booking_id=inn31426
# 0.000 booking_id=inn31427
# 0.000 booking_id=inn31428
# 0.000 booking_id=inn31429
# 0.000 booking_id=inn31430
# 0.000 booking_id=inn31431
# 0.000 booking_id=inn31432
# 0.000 booking_id=inn31433
# 0.000 booking_id=inn31434
# 0.000 booking_id=inn31435
# 0.000 booking_id=inn31436
# 0.000 booking_id=inn31437
# 0.000 booking_id=inn31438
# 0.000 booking_id=inn31439
# 0.000 booking_id=inn31440
# 0.000 booking_id=inn31442
# 0.000 booking_id=inn31443
# 0.000 booking_id=inn31444
# 0.000 booking_id=inn31446
# 0.000 booking_id=inn31447
# 0.000 booking_id=inn31448
# 0.000 booking_id=inn31449
# 0.000 booking_id=inn31451
# 0.000 booking_id=inn31452
# 0.000 booking_id=inn31453
# 0.000 booking_id=inn31455
# 0.000 booking_id=inn31456
# 0.000 booking_id=inn31457
# 0.000 booking_id=inn31459
# 0.000 booking_id=inn31460
# 0.000 booking_id=inn31461
# 0.000 booking_id=inn31463
# 0.000 booking_id=inn31465
# 0.000 booking_id=inn31466
# 0.000 booking_id=inn31467
# 0.000 booking_id=inn31468
# 0.000 booking_id=inn31469
# 0.000 booking_id=inn31470
# 0.000 booking_id=inn31472
# 0.000 booking_id=inn31474
# 0.000 booking_id=inn31476
# 0.000 booking_id=inn31477
# 0.000 booking_id=inn31479
# 0.000 booking_id=inn31480
# 0.000 booking_id=inn31481
# 0.000 booking_id=inn31482
# 0.000 booking_id=inn31483
# 0.000 booking_id=inn31484
# 0.000 booking_id=inn31485
# 0.000 booking_id=inn31486
# 0.000 booking_id=inn31487
# 0.000 booking_id=inn31488
# 0.000 booking_id=inn31489
# 0.000 booking_id=inn31490
# 0.000 booking_id=inn31491
# 0.000 booking_id=inn31493
# 0.000 booking_id=inn31494
# 0.000 booking_id=inn31495
# 0.000 booking_id=inn31496
# 0.000 booking_id=inn31497
# 0.000 booking_id=inn31498
# 0.000 booking_id=inn31499
# 0.000 booking_id=inn31500
# 0.000 booking_id=inn31501
# 0.000 booking_id=inn31502
# 0.000 booking_id=inn31504
# 0.000 booking_id=inn31505
# 0.000 booking_id=inn31507
# 0.000 booking_id=inn31509
# 0.000 booking_id=inn31510
# 0.000 booking_id=inn31511
# 0.000 booking_id=inn31512
# 0.000 booking_id=inn31515
# 0.000 booking_id=inn31516
# 0.000 booking_id=inn31518
# 0.000 booking_id=inn31519
# 0.000 booking_id=inn31520
# 0.000 booking_id=inn31521
# 0.000 booking_id=inn31522
# 0.000 booking_id=inn31524
# 0.000 booking_id=inn31525
# 0.000 booking_id=inn31527
# 0.000 booking_id=inn31529
# 0.000 booking_id=inn31530
# 0.000 booking_id=inn31531
# 0.000 booking_id=inn31532
# 0.000 booking_id=inn31533
# 0.000 booking_id=inn31534
# 0.000 booking_id=inn31535
# 0.000 booking_id=inn31537
# 0.000 booking_id=inn31539
# 0.000 booking_id=inn31540
# 0.000 booking_id=inn31541
# 0.000 booking_id=inn31542
# 0.000 booking_id=inn31543
# 0.000 booking_id=inn31544
# 0.000 booking_id=inn31545
# 0.000 booking_id=inn31546
# 0.000 booking_id=inn31547
# 0.000 booking_id=inn31548
# 0.000 booking_id=inn31549
# 0.000 booking_id=inn31550
# 0.000 booking_id=inn31551
# 0.000 booking_id=inn31552
# 0.000 booking_id=inn31555
# 0.000 booking_id=inn31556
# 0.000 booking_id=inn31558
# 0.000 booking_id=inn31559
# 0.000 booking_id=inn31561
# 0.000 booking_id=inn31562
# 0.000 booking_id=inn31563
# 0.000 booking_id=inn31564
# 0.000 booking_id=inn31565
# 0.000 booking_id=inn31567
# 0.000 booking_id=inn31568
# 0.000 booking_id=inn31569
# 0.000 booking_id=inn31570
# 0.000 booking_id=inn31571
# 0.000 booking_id=inn31573
# 0.000 booking_id=inn31574
# 0.000 booking_id=inn31577
# 0.000 booking_id=inn31578
# 0.000 booking_id=inn31579
# 0.000 booking_id=inn31580
# 0.000 booking_id=inn31581
# 0.000 booking_id=inn31583
# 0.000 booking_id=inn31584
# 0.000 booking_id=inn31585
# 0.000 booking_id=inn31586
# 0.000 booking_id=inn31587
# 0.000 booking_id=inn31588
# 0.000 booking_id=inn31589
# 0.000 booking_id=inn31590
# 0.000 booking_id=inn31591
# 0.000 booking_id=inn31592
# 0.000 booking_id=inn31593
# 0.000 booking_id=inn31595
# 0.000 booking_id=inn31596
# 0.000 booking_id=inn31597
# 0.000 booking_id=inn31598
# 0.000 booking_id=inn31599
# 0.000 booking_id=inn31600
# 0.000 booking_id=inn31601
# 0.000 booking_id=inn31602
# 0.000 booking_id=inn31603
# 0.000 booking_id=inn31605
# 0.000 booking_id=inn31607
# 0.000 booking_id=inn31610
# 0.000 booking_id=inn31612
# 0.000 booking_id=inn31613
# 0.000 booking_id=inn31614
# 0.000 booking_id=inn31615
# 0.000 booking_id=inn31616
# 0.000 booking_id=inn31618
# 0.000 booking_id=inn31619
# 0.000 booking_id=inn31620
# 0.000 booking_id=inn31621
# 0.000 booking_id=inn31622
# 0.000 booking_id=inn31623
# 0.000 booking_id=inn31624
# 0.000 booking_id=inn31626
# 0.000 booking_id=inn31628
# 0.000 booking_id=inn31631
# 0.000 booking_id=inn31633
# 0.000 booking_id=inn31635
# 0.000 booking_id=inn31637
# 0.000 booking_id=inn31638
# 0.000 booking_id=inn31639
# 0.000 booking_id=inn31640
# 0.000 booking_id=inn31641
# 0.000 booking_id=inn31642
# 0.000 booking_id=inn31643
# 0.000 booking_id=inn31645
# 0.000 booking_id=inn31646
# 0.000 booking_id=inn31647
# 0.000 booking_id=inn31648
# 0.000 booking_id=inn31649
# 0.000 booking_id=inn31650
# 0.000 booking_id=inn31651
# 0.000 booking_id=inn31652
# 0.000 booking_id=inn31653
# 0.000 booking_id=inn31654
# 0.000 booking_id=inn31655
# 0.000 booking_id=inn31657
# 0.000 booking_id=inn31658
# 0.000 booking_id=inn31659
# 0.000 booking_id=inn31660
# 0.000 booking_id=inn31661
# 0.000 booking_id=inn31662
# 0.000 booking_id=inn31664
# 0.000 booking_id=inn31666
# 0.000 booking_id=inn31667
# 0.000 booking_id=inn31669
# 0.000 booking_id=inn31670
# 0.000 booking_id=inn31671
# 0.000 booking_id=inn31673
# 0.000 booking_id=inn31674
# 0.000 booking_id=inn31675
# 0.000 booking_id=inn31676
# 0.000 booking_id=inn31677
# 0.000 booking_id=inn31678
# 0.000 booking_id=inn31679
# 0.000 booking_id=inn31680
# 0.000 booking_id=inn31681
# 0.000 booking_id=inn31682
# 0.000 booking_id=inn31684
# 0.000 booking_id=inn31686
# 0.000 booking_id=inn31687
# 0.000 booking_id=inn31688
# 0.000 booking_id=inn31689
# 0.000 booking_id=inn31690
# 0.000 booking_id=inn31691
# 0.000 booking_id=inn31692
# 0.000 booking_id=inn31693
# 0.000 booking_id=inn31694
# 0.000 booking_id=inn31695
# 0.000 booking_id=inn31696
# 0.000 booking_id=inn31697
# 0.000 booking_id=inn31699
# 0.000 booking_id=inn31700
# 0.000 booking_id=inn31701
# 0.000 booking_id=inn31702
# 0.000 booking_id=inn31703
# 0.000 booking_id=inn31705
# 0.000 booking_id=inn31706
# 0.000 booking_id=inn31707
# 0.000 booking_id=inn31708
# 0.000 booking_id=inn31709
# 0.000 booking_id=inn31710
# 0.000 booking_id=inn31711
# 0.000 booking_id=inn31712
# 0.000 booking_id=inn31713
# 0.000 booking_id=inn31714
# 0.000 booking_id=inn31715
# 0.000 booking_id=inn31716
# 0.000 booking_id=inn31718
# 0.000 booking_id=inn31719
# 0.000 booking_id=inn31720
# 0.000 booking_id=inn31721
# 0.000 booking_id=inn31722
# 0.000 booking_id=inn31723
# 0.000 booking_id=inn31725
# 0.000 booking_id=inn31726
# 0.000 booking_id=inn31727
# 0.000 booking_id=inn31728
# 0.000 booking_id=inn31729
# 0.000 booking_id=inn31731
# 0.000 booking_id=inn31732
# 0.000 booking_id=inn31733
# 0.000 booking_id=inn31734
# 0.000 booking_id=inn31735
# 0.000 booking_id=inn31736
# 0.000 booking_id=inn31737
# 0.000 booking_id=inn31739
# 0.000 booking_id=inn31740
# 0.000 booking_id=inn31741
# 0.000 booking_id=inn31742
# 0.000 booking_id=inn31744
# 0.000 booking_id=inn31745
# 0.000 booking_id=inn31746
# 0.000 booking_id=inn31747
# 0.000 booking_id=inn31748
# 0.000 booking_id=inn31749
# 0.000 booking_id=inn31750
# 0.000 booking_id=inn31751
# 0.000 booking_id=inn31752
# 0.000 booking_id=inn31753
# 0.000 booking_id=inn31754
# 0.000 booking_id=inn31755
# 0.000 booking_id=inn31756
# 0.000 booking_id=inn31757
# 0.000 booking_id=inn31758
# 0.000 booking_id=inn31760
# 0.000 booking_id=inn31761
# 0.000 booking_id=inn31762
# 0.000 booking_id=inn31763
# 0.000 booking_id=inn31764
# 0.000 booking_id=inn31766
# 0.000 booking_id=inn31767
# 0.000 booking_id=inn31769
# 0.000 booking_id=inn31770
# 0.000 booking_id=inn31771
# 0.000 booking_id=inn31772
# 0.000 booking_id=inn31773
# 0.000 booking_id=inn31774
# 0.000 booking_id=inn31776
# 0.000 booking_id=inn31777
# 0.000 booking_id=inn31778
# 0.000 booking_id=inn31780
# 0.000 booking_id=inn31781
# 0.000 booking_id=inn31782
# 0.000 booking_id=inn31786
# 0.000 booking_id=inn31787
# 0.000 booking_id=inn31788
# 0.000 booking_id=inn31789
# 0.000 booking_id=inn31790
# 0.000 booking_id=inn31791
# 0.000 booking_id=inn31792
# 0.000 booking_id=inn31793
# 0.000 booking_id=inn31794
# 0.000 booking_id=inn31795
# 0.000 booking_id=inn31796
# 0.000 booking_id=inn31797
# 0.000 booking_id=inn31798
# 0.000 booking_id=inn31799
# 0.000 booking_id=inn31800
# 0.000 booking_id=inn31801
# 0.000 booking_id=inn31804
# 0.000 booking_id=inn31805
# 0.000 booking_id=inn31806
# 0.000 booking_id=inn31807
# 0.000 booking_id=inn31808
# 0.000 booking_id=inn31809
# 0.000 booking_id=inn31810
# 0.000 booking_id=inn31812
# 0.000 booking_id=inn31813
# 0.000 booking_id=inn31815
# 0.000 booking_id=inn31816
# 0.000 booking_id=inn31817
# 0.000 booking_id=inn31818
# 0.000 booking_id=inn31819
# 0.000 booking_id=inn31820
# 0.000 booking_id=inn31821
# 0.000 booking_id=inn31822
# 0.000 booking_id=inn31824
# 0.000 booking_id=inn31825
# 0.000 booking_id=inn31826
# 0.000 booking_id=inn31827
# 0.000 booking_id=inn31828
# 0.000 booking_id=inn31829
# 0.000 booking_id=inn31830
# 0.000 booking_id=inn31831
# 0.000 booking_id=inn31832
# 0.000 booking_id=inn31833
# 0.000 booking_id=inn31835
# 0.000 booking_id=inn31836
# 0.000 booking_id=inn31838
# 0.000 booking_id=inn31839
# 0.000 booking_id=inn31840
# 0.000 booking_id=inn31841
# 0.000 booking_id=inn31843
# 0.000 booking_id=inn31844
# 0.000 booking_id=inn31845
# 0.000 booking_id=inn31846
# 0.000 booking_id=inn31847
# 0.000 booking_id=inn31848
# 0.000 booking_id=inn31849
# 0.000 booking_id=inn31850
# 0.000 booking_id=inn31851
# 0.000 booking_id=inn31853
# 0.000 booking_id=inn31854
# 0.000 booking_id=inn31856
# 0.000 booking_id=inn31857
# 0.000 booking_id=inn31859
# 0.000 booking_id=inn31860
# 0.000 booking_id=inn31861
# 0.000 booking_id=inn31862
# 0.000 booking_id=inn31864
# 0.000 booking_id=inn31865
# 0.000 booking_id=inn31866
# 0.000 booking_id=inn31867
# 0.000 booking_id=inn31868
# 0.000 booking_id=inn31869
# 0.000 booking_id=inn31870
# 0.000 booking_id=inn31872
# 0.000 booking_id=inn31874
# 0.000 booking_id=inn31875
# 0.000 booking_id=inn31877
# 0.000 booking_id=inn31878
# 0.000 booking_id=inn31879
# 0.000 booking_id=inn31880
# 0.000 booking_id=inn31881
# 0.000 booking_id=inn31882
# 0.000 booking_id=inn31883
# 0.000 booking_id=inn31885
# 0.000 booking_id=inn31886
# 0.000 booking_id=inn31887
# 0.000 booking_id=inn31888
# 0.000 booking_id=inn31889
# 0.000 booking_id=inn31890
# 0.000 booking_id=inn31891
# 0.000 booking_id=inn31893
# 0.000 booking_id=inn31894
# 0.000 booking_id=inn31895
# 0.000 booking_id=inn31897
# 0.000 booking_id=inn31899
# 0.000 booking_id=inn31901
# 0.000 booking_id=inn31902
# 0.000 booking_id=inn31903
# 0.000 booking_id=inn31904
# 0.000 booking_id=inn31905
# 0.000 booking_id=inn31906
# 0.000 booking_id=inn31907
# 0.000 booking_id=inn31909
# 0.000 booking_id=inn31910
# 0.000 booking_id=inn31911
# 0.000 booking_id=inn31914
# 0.000 booking_id=inn31915
# 0.000 booking_id=inn31916
# 0.000 booking_id=inn31917
# 0.000 booking_id=inn31919
# 0.000 booking_id=inn31920
# 0.000 booking_id=inn31921
# 0.000 booking_id=inn31922
# 0.000 booking_id=inn31923
# 0.000 booking_id=inn31924
# 0.000 booking_id=inn31925
# 0.000 booking_id=inn31926
# 0.000 booking_id=inn31927
# 0.000 booking_id=inn31929
# 0.000 booking_id=inn31930
# 0.000 booking_id=inn31931
# 0.000 booking_id=inn31934
# 0.000 booking_id=inn31937
# 0.000 booking_id=inn31938
# 0.000 booking_id=inn31939
# 0.000 booking_id=inn31941
# 0.000 booking_id=inn31942
# 0.000 booking_id=inn31943
# 0.000 booking_id=inn31944
# 0.000 booking_id=inn31946
# 0.000 booking_id=inn31947
# 0.000 booking_id=inn31948
# 0.000 booking_id=inn31949
# 0.000 booking_id=inn31951
# 0.000 booking_id=inn31952
# 0.000 booking_id=inn31953
# 0.000 booking_id=inn31954
# 0.000 booking_id=inn31956
# 0.000 booking_id=inn31957
# 0.000 booking_id=inn31959
# 0.000 booking_id=inn31960
# 0.000 booking_id=inn31961
# 0.000 booking_id=inn31962
# 0.000 booking_id=inn31964
# 0.000 booking_id=inn31966
# 0.000 booking_id=inn31967
# 0.000 booking_id=inn31969
# 0.000 booking_id=inn31970
# 0.000 booking_id=inn31972
# 0.000 booking_id=inn31973
# 0.000 booking_id=inn31975
# 0.000 booking_id=inn31976
# 0.000 booking_id=inn31977
# 0.000 booking_id=inn31979
# 0.000 booking_id=inn31980
# 0.000 booking_id=inn31982
# 0.000 booking_id=inn31983
# 0.000 booking_id=inn31984
# 0.000 booking_id=inn31986
# 0.000 booking_id=inn31987
# 0.000 booking_id=inn31988
# 0.000 booking_id=inn31991
# 0.000 booking_id=inn31992
# 0.000 booking_id=inn31993
# 0.000 booking_id=inn31994
# 0.000 booking_id=inn31995
# 0.000 booking_id=inn31996
# 0.000 booking_id=inn31997
# 0.000 booking_id=inn31998
# 0.000 booking_id=inn31999
# 0.000 booking_id=inn32000
# 0.000 booking_id=inn32001
# 0.000 booking_id=inn32002
# 0.000 booking_id=inn32003
# 0.000 booking_id=inn32005
# 0.000 booking_id=inn32006
# 0.000 booking_id=inn32008
# 0.000 booking_id=inn32009
# 0.000 booking_id=inn32010
# 0.000 booking_id=inn32011
# 0.000 booking_id=inn32012
# 0.000 booking_id=inn32013
# 0.000 booking_id=inn32014
# 0.000 booking_id=inn32015
# 0.000 booking_id=inn32016
# 0.000 booking_id=inn32017
# 0.000 booking_id=inn32018
# 0.000 booking_id=inn32019
# 0.000 booking_id=inn32020
# 0.000 booking_id=inn32021
# 0.000 booking_id=inn32022
# 0.000 booking_id=inn32023
# 0.000 booking_id=inn32025
# 0.000 booking_id=inn32026
# 0.000 booking_id=inn32027
# 0.000 booking_id=inn32028
# 0.000 booking_id=inn32029
# 0.000 booking_id=inn32030
# 0.000 booking_id=inn32031
# 0.000 booking_id=inn32032
# 0.000 booking_id=inn32033
# 0.000 booking_id=inn32034
# 0.000 booking_id=inn32035
# 0.000 booking_id=inn32036
# 0.000 booking_id=inn32037
# 0.000 booking_id=inn32038
# 0.000 booking_id=inn32039
# 0.000 booking_id=inn32040
# 0.000 booking_id=inn32041
# 0.000 booking_id=inn32043
# 0.000 booking_id=inn32044
# 0.000 booking_id=inn32046
# 0.000 booking_id=inn32047
# 0.000 booking_id=inn32048
# 0.000 booking_id=inn32049
# 0.000 booking_id=inn32050
# 0.000 booking_id=inn32052
# 0.000 booking_id=inn32053
# 0.000 booking_id=inn32054
# 0.000 booking_id=inn32055
# 0.000 booking_id=inn32056
# 0.000 booking_id=inn32057
# 0.000 booking_id=inn32058
# 0.000 booking_id=inn32061
# 0.000 booking_id=inn32062
# 0.000 booking_id=inn32063
# 0.000 booking_id=inn32064
# 0.000 booking_id=inn32065
# 0.000 booking_id=inn32066
# 0.000 booking_id=inn32067
# 0.000 booking_id=inn32068
# 0.000 booking_id=inn32069
# 0.000 booking_id=inn32070
# 0.000 booking_id=inn32071
# 0.000 booking_id=inn32072
# 0.000 booking_id=inn32075
# 0.000 booking_id=inn32076
# 0.000 booking_id=inn32077
# 0.000 booking_id=inn32078
# 0.000 booking_id=inn32079
# 0.000 booking_id=inn32080
# 0.000 booking_id=inn32081
# 0.000 booking_id=inn32082
# 0.000 booking_id=inn32083
# 0.000 booking_id=inn32084
# 0.000 booking_id=inn32085
# 0.000 booking_id=inn32086
# 0.000 booking_id=inn32088
# 0.000 booking_id=inn32091
# 0.000 booking_id=inn32093
# 0.000 booking_id=inn32094
# 0.000 booking_id=inn32095
# 0.000 booking_id=inn32096
# 0.000 booking_id=inn32097
# 0.000 booking_id=inn32098
# 0.000 booking_id=inn32099
# 0.000 booking_id=inn32101
# 0.000 booking_id=inn32103
# 0.000 booking_id=inn32105
# 0.000 booking_id=inn32106
# 0.000 booking_id=inn32109
# 0.000 booking_id=inn32110
# 0.000 booking_id=inn32111
# 0.000 booking_id=inn32112
# 0.000 booking_id=inn32113
# 0.000 booking_id=inn32114
# 0.000 booking_id=inn32115
# 0.000 booking_id=inn32116
# 0.000 booking_id=inn32117
# 0.000 booking_id=inn32118
# 0.000 booking_id=inn32119
# 0.000 booking_id=inn32120
# 0.000 booking_id=inn32121
# 0.000 booking_id=inn32122
# 0.000 booking_id=inn32123
# 0.000 booking_id=inn32124
# 0.000 booking_id=inn32125
# 0.000 booking_id=inn32126
# 0.000 booking_id=inn32128
# 0.000 booking_id=inn32129
# 0.000 booking_id=inn32130
# 0.000 booking_id=inn32131
# 0.000 booking_id=inn32132
# 0.000 booking_id=inn32134
# 0.000 booking_id=inn32135
# 0.000 booking_id=inn32136
# 0.000 booking_id=inn32137
# 0.000 booking_id=inn32138
# 0.000 booking_id=inn32139
# 0.000 booking_id=inn32140
# 0.000 booking_id=inn32141
# 0.000 booking_id=inn32146
# 0.000 booking_id=inn32147
# 0.000 booking_id=inn32148
# 0.000 booking_id=inn32149
# 0.000 booking_id=inn32150
# 0.000 booking_id=inn32151
# 0.000 booking_id=inn32153
# 0.000 booking_id=inn32154
# 0.000 booking_id=inn32155
# 0.000 booking_id=inn32156
# 0.000 booking_id=inn32157
# 0.000 booking_id=inn32158
# 0.000 booking_id=inn32160
# 0.000 booking_id=inn32161
# 0.000 booking_id=inn32163
# 0.000 booking_id=inn32164
# 0.000 booking_id=inn32166
# 0.000 booking_id=inn32168
# 0.000 booking_id=inn32169
# 0.000 booking_id=inn32170
# 0.000 booking_id=inn32171
# 0.000 booking_id=inn32172
# 0.000 booking_id=inn32173
# 0.000 booking_id=inn32175
# 0.000 booking_id=inn32177
# 0.000 booking_id=inn32178
# 0.000 booking_id=inn32180
# 0.000 booking_id=inn32182
# 0.000 booking_id=inn32183
# 0.000 booking_id=inn32184
# 0.000 booking_id=inn32185
# 0.000 booking_id=inn32188
# 0.000 booking_id=inn32189
# 0.000 booking_id=inn32190
# 0.000 booking_id=inn32191
# 0.000 booking_id=inn32193
# 0.000 booking_id=inn32194
# 0.000 booking_id=inn32195
# 0.000 booking_id=inn32196
# 0.000 booking_id=inn32197
# 0.000 booking_id=inn32198
# 0.000 booking_id=inn32199
# 0.000 booking_id=inn32200
# 0.000 booking_id=inn32201
# 0.000 booking_id=inn32203
# 0.000 booking_id=inn32204
# 0.000 booking_id=inn32205
# 0.000 booking_id=inn32206
# 0.000 booking_id=inn32207
# 0.000 booking_id=inn32208
# 0.000 booking_id=inn32209
# 0.000 booking_id=inn32210
# 0.000 booking_id=inn32211
# 0.000 booking_id=inn32212
# 0.000 booking_id=inn32213
# 0.000 booking_id=inn32214
# 0.000 booking_id=inn32215
# 0.000 booking_id=inn32216
# 0.000 booking_id=inn32217
# 0.000 booking_id=inn32218
# 0.000 booking_id=inn32219
# 0.000 booking_id=inn32220
# 0.000 booking_id=inn32222
# 0.000 booking_id=inn32223
# 0.000 booking_id=inn32224
# 0.000 booking_id=inn32226
# 0.000 booking_id=inn32227
# 0.000 booking_id=inn32228
# 0.000 booking_id=inn32230
# 0.000 booking_id=inn32232
# 0.000 booking_id=inn32235
# 0.000 booking_id=inn32236
# 0.000 booking_id=inn32237
# 0.000 booking_id=inn32238
# 0.000 booking_id=inn32240
# 0.000 booking_id=inn32241
# 0.000 booking_id=inn32242
# 0.000 booking_id=inn32244
# 0.000 booking_id=inn32245
# 0.000 booking_id=inn32246
# 0.000 booking_id=inn32248
# 0.000 booking_id=inn32249
# 0.000 booking_id=inn32251
# 0.000 booking_id=inn32252
# 0.000 booking_id=inn32253
# 0.000 booking_id=inn32254
# 0.000 booking_id=inn32255
# 0.000 booking_id=inn32256
# 0.000 booking_id=inn32257
# 0.000 booking_id=inn32258
# 0.000 booking_id=inn32259
# 0.000 booking_id=inn32262
# 0.000 booking_id=inn32263
# 0.000 booking_id=inn32265
# 0.000 booking_id=inn32267
# 0.000 booking_id=inn32269
# 0.000 booking_id=inn32270
# 0.000 booking_id=inn32272
# 0.000 booking_id=inn32273
# 0.000 booking_id=inn32274
# 0.000 booking_id=inn32275
# 0.000 booking_id=inn32276
# 0.000 booking_id=inn32277
# 0.000 booking_id=inn32278
# 0.000 booking_id=inn32280
# 0.000 booking_id=inn32281
# 0.000 booking_id=inn32282
# 0.000 booking_id=inn32283
# 0.000 booking_id=inn32284
# 0.000 booking_id=inn32285
# 0.000 booking_id=inn32286
# 0.000 booking_id=inn32287
# 0.000 booking_id=inn32289
# 0.000 booking_id=inn32290
# 0.000 booking_id=inn32291
# 0.000 booking_id=inn32292
# 0.000 booking_id=inn32294
# 0.000 booking_id=inn32295
# 0.000 booking_id=inn32296
# 0.000 booking_id=inn32297
# 0.000 booking_id=inn32298
# 0.000 booking_id=inn32299
# 0.000 booking_id=inn32300
# 0.000 booking_id=inn32302
# 0.000 booking_id=inn32305
# 0.000 booking_id=inn32306
# 0.000 booking_id=inn32307
# 0.000 booking_id=inn32308
# ...
# 0.000 booking_id=inn35529
# 0.000 booking_id=inn35530
# 0.000 booking_id=inn35531
# 0.000 booking_id=inn35532
# 0.000 booking_id=inn35535
# 0.000 booking_id=inn35536
# 0.000 booking_id=inn35537
# 0.000 booking_id=inn35539
# 0.000 booking_id=inn35540
# 0.000 booking_id=inn35541
# 0.000 booking_id=inn35542
# 0.000 booking_id=inn35543
# 0.000 booking_id=inn35544
# 0.000 booking_id=inn35545
# 0.000 booking_id=inn35546
# 0.000 booking_id=inn35547
# 0.000 booking_id=inn35548
# 0.000 booking_id=inn35549
# 0.000 booking_id=inn35550
# 0.000 booking_id=inn35554
# 0.000 booking_id=inn35555
# 0.000 booking_id=inn35556
# 0.000 booking_id=inn35557
# 0.000 booking_id=inn35558
# 0.000 booking_id=inn35559
# 0.000 booking_id=inn35561
# 0.000 booking_id=inn35563
# 0.000 booking_id=inn35564
# 0.000 booking_id=inn35565
# 0.000 booking_id=inn35566
# 0.000 booking_id=inn35568
# 0.000 booking_id=inn35569
# 0.000 booking_id=inn35570
# 0.000 booking_id=inn35571
# 0.000 booking_id=inn35572
# 0.000 booking_id=inn35573
# 0.000 booking_id=inn35574
# 0.000 booking_id=inn35576
# 0.000 booking_id=inn35577
# 0.000 booking_id=inn35579
# 0.000 booking_id=inn35581
# 0.000 booking_id=inn35582
# 0.000 booking_id=inn35585
# 0.000 booking_id=inn35586
# 0.000 booking_id=inn35589
# 0.000 booking_id=inn35590
# 0.000 booking_id=inn35591
# 0.000 booking_id=inn35592
# 0.000 booking_id=inn35594
# 0.000 booking_id=inn35595
# 0.000 booking_id=inn35596
# 0.000 booking_id=inn35597
# 0.000 booking_id=inn35600
# 0.000 booking_id=inn35601
# 0.000 booking_id=inn35603
# 0.000 booking_id=inn35604
# 0.000 booking_id=inn35605
# 0.000 booking_id=inn35606
# 0.000 booking_id=inn35607
# 0.000 booking_id=inn35608
# 0.000 booking_id=inn35610
# 0.000 booking_id=inn35611
# 0.000 booking_id=inn35612
# 0.000 booking_id=inn35613
# 0.000 booking_id=inn35614
# 0.000 booking_id=inn35615
# 0.000 booking_id=inn35616
# 0.000 booking_id=inn35617
# 0.000 booking_id=inn35618
# 0.000 booking_id=inn35619
# 0.000 booking_id=inn35622
# 0.000 booking_id=inn35623
# 0.000 booking_id=inn35625
# 0.000 booking_id=inn35626
# 0.000 booking_id=inn35628
# 0.000 booking_id=inn35629
# 0.000 booking_id=inn35630
# 0.000 booking_id=inn35631
# 0.000 booking_id=inn35634
# 0.000 booking_id=inn35635
# 0.000 booking_id=inn35636
# 0.000 booking_id=inn35639
# 0.000 booking_id=inn35640
# 0.000 booking_id=inn35643
# 0.000 booking_id=inn35644
# 0.000 booking_id=inn35645
# 0.000 booking_id=inn35646
# 0.000 booking_id=inn35648
# 0.000 booking_id=inn35649
# 0.000 booking_id=inn35650
# 0.000 booking_id=inn35651
# 0.000 booking_id=inn35654
# 0.000 booking_id=inn35655
# 0.000 booking_id=inn35657
# 0.000 booking_id=inn35658
# 0.000 booking_id=inn35659
# 0.000 booking_id=inn35661
# 0.000 booking_id=inn35662
# 0.000 booking_id=inn35663
# 0.000 booking_id=inn35664
# 0.000 booking_id=inn35666
# 0.000 booking_id=inn35667
# 0.000 booking_id=inn35669
# 0.000 booking_id=inn35670
# 0.000 booking_id=inn35671
# 0.000 booking_id=inn35672
# 0.000 booking_id=inn35673
# 0.000 booking_id=inn35674
# 0.000 booking_id=inn35676
# 0.000 booking_id=inn35677
# 0.000 booking_id=inn35679
# 0.000 booking_id=inn35680
# 0.000 booking_id=inn35681
# 0.000 booking_id=inn35682
# 0.000 booking_id=inn35683
# 0.000 booking_id=inn35684
# 0.000 booking_id=inn35685
# 0.000 booking_id=inn35686
# 0.000 booking_id=inn35688
# 0.000 booking_id=inn35689
# 0.000 booking_id=inn35690
# 0.000 booking_id=inn35691
# 0.000 booking_id=inn35692
# 0.000 booking_id=inn35693
# 0.000 booking_id=inn35694
# 0.000 booking_id=inn35695
# 0.000 booking_id=inn35696
# 0.000 booking_id=inn35697
# 0.000 booking_id=inn35698
# 0.000 booking_id=inn35699
# 0.000 booking_id=inn35700
# 0.000 booking_id=inn35701
# 0.000 booking_id=inn35703
# 0.000 booking_id=inn35704
# 0.000 booking_id=inn35707
# 0.000 booking_id=inn35708
# 0.000 booking_id=inn35709
# 0.000 booking_id=inn35711
# 0.000 booking_id=inn35713
# 0.000 booking_id=inn35714
# 0.000 booking_id=inn35715
# 0.000 booking_id=inn35716
# 0.000 booking_id=inn35718
# 0.000 booking_id=inn35719
# 0.000 booking_id=inn35720
# 0.000 booking_id=inn35722
# 0.000 booking_id=inn35723
# 0.000 booking_id=inn35724
# 0.000 booking_id=inn35726
# 0.000 booking_id=inn35727
# 0.000 booking_id=inn35730
# 0.000 booking_id=inn35731
# 0.000 booking_id=inn35732
# 0.000 booking_id=inn35733
# 0.000 booking_id=inn35734
# 0.000 booking_id=inn35735
# 0.000 booking_id=inn35736
# 0.000 booking_id=inn35737
# 0.000 booking_id=inn35738
# 0.000 booking_id=inn35739
# 0.000 booking_id=inn35740
# 0.000 booking_id=inn35741
# 0.000 booking_id=inn35743
# 0.000 booking_id=inn35745
# 0.000 booking_id=inn35746
# 0.000 booking_id=inn35747
# 0.000 booking_id=inn35748
# 0.000 booking_id=inn35749
# 0.000 booking_id=inn35752
# 0.000 booking_id=inn35753
# 0.000 booking_id=inn35754
# 0.000 booking_id=inn35755
# 0.000 booking_id=inn35757
# 0.000 booking_id=inn35758
# 0.000 booking_id=inn35760
# 0.000 booking_id=inn35761
# 0.000 booking_id=inn35762
# 0.000 booking_id=inn35763
# 0.000 booking_id=inn35764
# 0.000 booking_id=inn35765
# 0.000 booking_id=inn35767
# 0.000 booking_id=inn35768
# 0.000 booking_id=inn35769
# 0.000 booking_id=inn35770
# 0.000 booking_id=inn35771
# 0.000 booking_id=inn35772
# 0.000 booking_id=inn35773
# 0.000 booking_id=inn35777
# 0.000 booking_id=inn35779
# 0.000 booking_id=inn35780
# 0.000 booking_id=inn35781
# 0.000 booking_id=inn35782
# 0.000 booking_id=inn35783
# 0.000 booking_id=inn35784
# 0.000 booking_id=inn35785
# 0.000 booking_id=inn35786
# 0.000 booking_id=inn35787
# 0.000 booking_id=inn35788
# 0.000 booking_id=inn35789
# 0.000 booking_id=inn35791
# 0.000 booking_id=inn35792
# 0.000 booking_id=inn35793
# 0.000 booking_id=inn35794
# 0.000 booking_id=inn35795
# 0.000 booking_id=inn35796
# 0.000 booking_id=inn35797
# 0.000 booking_id=inn35798
# 0.000 booking_id=inn35799
# 0.000 booking_id=inn35801
# 0.000 booking_id=inn35802
# 0.000 booking_id=inn35803
# 0.000 booking_id=inn35804
# 0.000 booking_id=inn35805
# 0.000 booking_id=inn35806
# 0.000 booking_id=inn35807
# 0.000 booking_id=inn35808
# 0.000 booking_id=inn35809
# 0.000 booking_id=inn35810
# 0.000 booking_id=inn35813
# 0.000 booking_id=inn35814
# 0.000 booking_id=inn35816
# 0.000 booking_id=inn35817
# 0.000 booking_id=inn35818
# 0.000 booking_id=inn35819
# 0.000 booking_id=inn35821
# 0.000 booking_id=inn35822
# 0.000 booking_id=inn35823
# 0.000 booking_id=inn35824
# 0.000 booking_id=inn35825
# 0.000 booking_id=inn35826
# 0.000 booking_id=inn35829
# 0.000 booking_id=inn35830
# 0.000 booking_id=inn35832
# 0.000 booking_id=inn35833
# 0.000 booking_id=inn35834
# 0.000 booking_id=inn35835
# 0.000 booking_id=inn35837
# 0.000 booking_id=inn35838
# 0.000 booking_id=inn35839
# 0.000 booking_id=inn35841
# 0.000 booking_id=inn35843
# 0.000 booking_id=inn35844
# 0.000 booking_id=inn35846
# 0.000 booking_id=inn35848
# 0.000 booking_id=inn35850
# 0.000 booking_id=inn35851
# 0.000 booking_id=inn35852
# 0.000 booking_id=inn35856
# 0.000 booking_id=inn35857
# 0.000 booking_id=inn35858
# 0.000 booking_id=inn35859
# 0.000 booking_id=inn35860
# 0.000 booking_id=inn35862
# 0.000 booking_id=inn35863
# 0.000 booking_id=inn35864
# 0.000 booking_id=inn35865
# 0.000 booking_id=inn35866
# 0.000 booking_id=inn35867
# 0.000 booking_id=inn35869
# 0.000 booking_id=inn35870
# 0.000 booking_id=inn35871
# 0.000 booking_id=inn35872
# 0.000 booking_id=inn35873
# 0.000 booking_id=inn35874
# 0.000 booking_id=inn35875
# 0.000 booking_id=inn35876
# 0.000 booking_id=inn35877
# 0.000 booking_id=inn35878
# 0.000 booking_id=inn35879
# 0.000 booking_id=inn35880
# 0.000 booking_id=inn35881
# 0.000 booking_id=inn35883
# 0.000 booking_id=inn35884
# 0.000 booking_id=inn35886
# 0.000 booking_id=inn35887
# 0.000 booking_id=inn35888
# 0.000 booking_id=inn35892
# 0.000 booking_id=inn35893
# 0.000 booking_id=inn35894
# 0.000 booking_id=inn35895
# 0.000 booking_id=inn35896
# 0.000 booking_id=inn35897
# 0.000 booking_id=inn35898
# 0.000 booking_id=inn35899
# 0.000 booking_id=inn35901
# 0.000 booking_id=inn35902
# 0.000 booking_id=inn35903
# 0.000 booking_id=inn35904
# 0.000 booking_id=inn35905
# 0.000 booking_id=inn35906
# 0.000 booking_id=inn35910
# 0.000 booking_id=inn35911
# 0.000 booking_id=inn35914
# 0.000 booking_id=inn35915
# 0.000 booking_id=inn35916
# 0.000 booking_id=inn35917
# 0.000 booking_id=inn35918
# 0.000 booking_id=inn35919
# 0.000 booking_id=inn35920
# 0.000 booking_id=inn35921
# 0.000 booking_id=inn35922
# 0.000 booking_id=inn35923
# 0.000 booking_id=inn35924
# 0.000 booking_id=inn35925
# 0.000 booking_id=inn35926
# 0.000 booking_id=inn35928
# 0.000 booking_id=inn35929
# 0.000 booking_id=inn35930
# 0.000 booking_id=inn35931
# 0.000 booking_id=inn35932
# 0.000 booking_id=inn35933
# 0.000 booking_id=inn35935
# 0.000 booking_id=inn35936
# 0.000 booking_id=inn35940
# 0.000 booking_id=inn35942
# 0.000 booking_id=inn35943
# 0.000 booking_id=inn35944
# 0.000 booking_id=inn35946
# 0.000 booking_id=inn35947
# 0.000 booking_id=inn35948
# 0.000 booking_id=inn35949
# 0.000 booking_id=inn35950
# 0.000 booking_id=inn35951
# 0.000 booking_id=inn35952
# 0.000 booking_id=inn35953
# 0.000 booking_id=inn35954
# 0.000 booking_id=inn35955
# 0.000 booking_id=inn35956
# 0.000 booking_id=inn35957
# 0.000 booking_id=inn35959
# 0.000 booking_id=inn35961
# 0.000 booking_id=inn35962
# 0.000 booking_id=inn35963
# 0.000 booking_id=inn35964
# 0.000 booking_id=inn35965
# 0.000 booking_id=inn35966
# 0.000 booking_id=inn35967
# 0.000 booking_id=inn35968
# 0.000 booking_id=inn35969
# 0.000 booking_id=inn35971
# 0.000 booking_id=inn35972
# 0.000 booking_id=inn35973
# 0.000 booking_id=inn35974
# 0.000 booking_id=inn35976
# 0.000 booking_id=inn35977
# 0.000 booking_id=inn35978
# 0.000 booking_id=inn35979
# 0.000 booking_id=inn35981
# 0.000 booking_id=inn35982
# 0.000 booking_id=inn35983
# 0.000 booking_id=inn35984
# 0.000 booking_id=inn35987
# 0.000 booking_id=inn35988
# 0.000 booking_id=inn35991
# 0.000 booking_id=inn35992
# 0.000 booking_id=inn35993
# 0.000 booking_id=inn35994
# 0.000 booking_id=inn35995
# 0.000 booking_id=inn35996
# 0.000 booking_id=inn35997
# 0.000 booking_id=inn35998
# 0.000 booking_id=inn35999
# 0.000 booking_id=inn36000
# 0.000 booking_id=inn36001
# 0.000 booking_id=inn36002
# 0.000 booking_id=inn36003
# 0.000 booking_id=inn36004
# 0.000 booking_id=inn36005
# 0.000 booking_id=inn36006
# 0.000 booking_id=inn36007
# 0.000 booking_id=inn36009
# 0.000 booking_id=inn36010
# 0.000 booking_id=inn36011
# 0.000 booking_id=inn36012
# 0.000 booking_id=inn36015
# 0.000 booking_id=inn36016
# 0.000 booking_id=inn36018
# 0.000 booking_id=inn36019
# 0.000 booking_id=inn36020
# 0.000 booking_id=inn36021
# 0.000 booking_id=inn36022
# 0.000 booking_id=inn36023
# 0.000 booking_id=inn36024
# 0.000 booking_id=inn36025
# 0.000 booking_id=inn36026
# 0.000 booking_id=inn36027
# 0.000 booking_id=inn36029
# 0.000 booking_id=inn36030
# 0.000 booking_id=inn36031
# 0.000 booking_id=inn36032
# 0.000 booking_id=inn36033
# 0.000 booking_id=inn36034
# 0.000 booking_id=inn36035
# 0.000 booking_id=inn36036
# 0.000 booking_id=inn36037
# 0.000 booking_id=inn36039
# 0.000 booking_id=inn36040
# 0.000 booking_id=inn36041
# 0.000 booking_id=inn36042
# 0.000 booking_id=inn36043
# 0.000 booking_id=inn36044
# 0.000 booking_id=inn36047
# 0.000 booking_id=inn36049
# 0.000 booking_id=inn36051
# 0.000 booking_id=inn36052
# 0.000 booking_id=inn36053
# 0.000 booking_id=inn36054
# 0.000 booking_id=inn36055
# 0.000 booking_id=inn36059
# 0.000 booking_id=inn36060
# 0.000 booking_id=inn36061
# 0.000 booking_id=inn36063
# 0.000 booking_id=inn36064
# 0.000 booking_id=inn36065
# 0.000 booking_id=inn36066
# 0.000 booking_id=inn36068
# 0.000 booking_id=inn36070
# 0.000 booking_id=inn36071
# 0.000 booking_id=inn36072
# 0.000 booking_id=inn36073
# 0.000 booking_id=inn36074
# 0.000 booking_id=inn36075
# 0.000 booking_id=inn36076
# 0.000 booking_id=inn36077
# 0.000 booking_id=inn36079
# 0.000 booking_id=inn36080
# 0.000 booking_id=inn36081
# 0.000 booking_id=inn36082
# 0.000 booking_id=inn36083
# 0.000 booking_id=inn36084
# 0.000 booking_id=inn36085
# 0.000 booking_id=inn36086
# 0.000 booking_id=inn36087
# 0.000 booking_id=inn36088
# 0.000 booking_id=inn36089
# 0.000 booking_id=inn36090
# 0.000 booking_id=inn36091
# 0.000 booking_id=inn36092
# 0.000 booking_id=inn36093
# 0.000 booking_id=inn36094
# 0.000 booking_id=inn36096
# 0.000 booking_id=inn36098
# 0.000 booking_id=inn36101
# 0.000 booking_id=inn36103
# 0.000 booking_id=inn36105
# 0.000 booking_id=inn36106
# 0.000 booking_id=inn36107
# 0.000 booking_id=inn36108
# 0.000 booking_id=inn36109
# 0.000 booking_id=inn36110
# 0.000 booking_id=inn36111
# 0.000 booking_id=inn36112
# 0.000 booking_id=inn36113
# 0.000 booking_id=inn36114
# 0.000 booking_id=inn36115
# 0.000 booking_id=inn36116
# 0.000 booking_id=inn36117
# 0.000 booking_id=inn36119
# 0.000 booking_id=inn36120
# 0.000 booking_id=inn36122
# 0.000 booking_id=inn36123
# 0.000 booking_id=inn36124
# 0.000 booking_id=inn36125
# 0.000 booking_id=inn36126
# 0.000 booking_id=inn36129
# 0.000 booking_id=inn36130
# 0.000 booking_id=inn36132
# 0.000 booking_id=inn36134
# 0.000 booking_id=inn36135
# 0.000 booking_id=inn36137
# 0.000 booking_id=inn36139
# 0.000 booking_id=inn36140
# 0.000 booking_id=inn36141
# 0.000 booking_id=inn36142
# 0.000 booking_id=inn36143
# 0.000 booking_id=inn36144
# 0.000 booking_id=inn36145
# 0.000 booking_id=inn36146
# 0.000 booking_id=inn36147
# 0.000 booking_id=inn36148
# 0.000 booking_id=inn36149
# 0.000 booking_id=inn36151
# 0.000 booking_id=inn36154
# 0.000 booking_id=inn36155
# 0.000 booking_id=inn36157
# 0.000 booking_id=inn36158
# 0.000 booking_id=inn36159
# 0.000 booking_id=inn36161
# 0.000 booking_id=inn36162
# 0.000 booking_id=inn36163
# 0.000 booking_id=inn36164
# 0.000 booking_id=inn36167
# 0.000 booking_id=inn36168
# 0.000 booking_id=inn36170
# 0.000 booking_id=inn36171
# 0.000 booking_id=inn36172
# 0.000 booking_id=inn36173
# 0.000 booking_id=inn36174
# 0.000 booking_id=inn36175
# 0.000 booking_id=inn36176
# 0.000 booking_id=inn36177
# 0.000 booking_id=inn36178
# 0.000 booking_id=inn36179
# 0.000 booking_id=inn36180
# 0.000 booking_id=inn36182
# 0.000 booking_id=inn36183
# 0.000 booking_id=inn36185
# 0.000 booking_id=inn36186
# 0.000 booking_id=inn36187
# 0.000 booking_id=inn36188
# 0.000 booking_id=inn36189
# 0.000 booking_id=inn36190
# 0.000 booking_id=inn36191
# 0.000 booking_id=inn36192
# 0.000 booking_id=inn36193
# 0.000 booking_id=inn36194
# 0.000 booking_id=inn36195
# 0.000 booking_id=inn36196
# 0.000 booking_id=inn36197
# 0.000 booking_id=inn36198
# 0.000 booking_id=inn36199
# 0.000 booking_id=inn36200
# 0.000 booking_id=inn36201
# 0.000 booking_id=inn36203
# 0.000 booking_id=inn36204
# 0.000 booking_id=inn36205
# 0.000 booking_id=inn36206
# 0.000 booking_id=inn36207
# 0.000 booking_id=inn36208
# 0.000 booking_id=inn36209
# 0.000 booking_id=inn36210
# 0.000 booking_id=inn36211
# 0.000 booking_id=inn36212
# 0.000 booking_id=inn36213
# 0.000 booking_id=inn36214
# 0.000 booking_id=inn36215
# 0.000 booking_id=inn36216
# 0.000 booking_id=inn36217
# 0.000 booking_id=inn36219
# 0.000 booking_id=inn36222
# 0.000 booking_id=inn36225
# 0.000 booking_id=inn36226
# 0.000 booking_id=inn36227
# 0.000 booking_id=inn36228
# 0.000 booking_id=inn36229
# 0.000 booking_id=inn36230
# 0.000 booking_id=inn36231
# 0.000 booking_id=inn36232
# 0.000 booking_id=inn36236
# 0.000 booking_id=inn36237
# 0.000 booking_id=inn36238
# 0.000 booking_id=inn36239
# 0.000 booking_id=inn36240
# 0.000 booking_id=inn36242
# 0.000 booking_id=inn36243
# 0.000 booking_id=inn36244
# 0.000 booking_id=inn36245
# 0.000 booking_id=inn36246
# 0.000 booking_id=inn36248
# 0.000 booking_id=inn36249
# 0.000 booking_id=inn36250
# 0.000 booking_id=inn36253
# 0.000 booking_id=inn36254
# 0.000 booking_id=inn36255
# 0.000 booking_id=inn36256
# 0.000 booking_id=inn36257
# 0.000 booking_id=inn36258
# 0.000 booking_id=inn36259
# 0.000 booking_id=inn36261
# 0.000 booking_id=inn36262
# 0.000 booking_id=inn36263
# 0.000 booking_id=inn36264
# 0.000 booking_id=inn36265
# 0.000 booking_id=inn36266
# 0.000 booking_id=inn36267
# 0.000 booking_id=inn36268
# 0.000 booking_id=inn36269
# 0.000 booking_id=inn36270
# 0.000 booking_id=inn36271
# 0.000 booking_id=inn36272
# 0.000 booking_id=inn36273
# 0.000 booking_id=inn36274
# 0.300 lead_time
# 0.000 market_segment_type=aviation
# 0.000 market_segment_type=complementary
# 0.001 market_segment_type=corporate
# 0.001 market_segment_type=offline
# 0.093 market_segment_type=online
# 0.021 no_of_adults
# 0.002 no_of_children
# 0.000 no_of_previous_bookings_not_canceled
# 0.000 no_of_previous_cancellations
# 0.068 no_of_special_requests
# 0.025 no_of_week_nights
# 0.021 no_of_weekend_nights
# 0.000 repeated_guest
# 0.007 required_car_parking_space
# 0.002 room_type_reserved=room_type_1
# 0.001 room_type_reserved=room_type_2
# 0.000 room_type_reserved=room_type_3
# 0.005 room_type_reserved=room_type_4
# 0.001 room_type_reserved=room_type_5
# 0.000 room_type_reserved=room_type_6
# 0.000 room_type_reserved=room_type_7
# 0.004 type_of_meal_plan=meal_plan_1
# 0.001 type_of_meal_plan=meal_plan_2
# 0.000 type_of_meal_plan=meal_plan_3
# 0.002 type_of_meal_plan=not_selected

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
import matplotlib.pyplot as plt
# predict_proba predicts the probability and predict just predicts the category
# y_pred = dt.predict_proba(X_test)[:, 1]
y_pred = dt.predict(X_test)

conf_matrix = confusion_matrix(y_true=y_test, y_pred=y_pred)
#
# Print the confusion matrix using Matplotlib
#
fig, ax = plt.subplots(figsize=(5, 5))
ax.matshow(conf_matrix, cmap=plt.cm.Oranges, alpha=0.3)
for i in range(conf_matrix.shape[0]):
    for j in range(conf_matrix.shape[1]):
        ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size='xx-large')
 
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.title('Confusion Matrix', fontsize=18)
plt.show()
# Out:
# Text(0, 0, '1523')
# Text(1, 0, '886')
# Text(0, 1, '435')
# Text(1, 1, '4411')
# Text(0.5, 0, 'Predictions')
# Text(0, 0.5, 'Actuals')
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     canceled       0.78      0.63      0.70      2409
# not_canceled       0.83      0.91      0.87      4846
#
#     accuracy                           0.82      7255
#    macro avg       0.81      0.77      0.78      7255
# weighted avg       0.81      0.82      0.81      7255

# %%
# How to make predictions with BRAND NEW VALUES
type(df_train_full.head(1))
# Out:
# pandas.core.frame.DataFrame

# %%
# Use double brackets around the iloc to force it to return a pandas dataframe and not a series
# Then you can convert ANY record into a dictionary.
# This is important because when you want to make a prediction - it must be in this format
df_train_full.iloc[[21]]

# %%
# How to convert any pandas row into a dictionary... needed for predictions
df_train_full.iloc[[213]].to_dict('records')[0]
# Out:
# {'booking_id': 'inn25419',
#  'no_of_adults': 2,
#  'no_of_children': 0,
#  'no_of_weekend_nights': 0,
#  'no_of_week_nights': 1,
#  'type_of_meal_plan': 'not_selected',
#  'required_car_parking_space': 0,
#  'room_type_reserved': 'room_type_1',
#  'lead_time': 51,
#  'arrival_year': 2018,
#  'arrival_month': 7,
#  'arrival_date': 6,
#  'market_segment_type': 'online',
#  'repeated_guest': 0,
#  'no_of_previous_cancellations': 0,
#  'no_of_previous_bookings_not_canceled': 0,
#  'avg_price_per_room': 107.1,
#  'no_of_special_requests': 0}

# %%
# How to convert any pandas row into a dictionary... needed for predictions
df_train_full.head(21).to_dict('records')[0]
# Out:
# {'booking_id': 'inn34124',
#  'no_of_adults': 2,
#  'no_of_children': 0,
#  'no_of_weekend_nights': 0,
#  'no_of_week_nights': 2,
#  'type_of_meal_plan': 'not_selected',
#  'required_car_parking_space': 0,
#  'room_type_reserved': 'room_type_1',
#  'lead_time': 12,
#  'arrival_year': 2018,
#  'arrival_month': 1,
#  'arrival_date': 22,
#  'market_segment_type': 'online',
#  'repeated_guest': 0,
#  'no_of_previous_cancellations': 0,
#  'no_of_previous_bookings_not_canceled': 0,
#  'avg_price_per_room': 75.0,
#  'no_of_special_requests': 0}

# %%
#item = df_train.head(1).to_dict('records')[0]
item = df_train_full.iloc[[213]].to_dict('records')[0]
actual = y_train[[213]]

# %%
# The item to be predicted is passed in.  
def model_prediction(item, dv, model):
    X = dv.transform([item])
    y_pred = model.predict(X)
    return y_pred[0]

# %%
# The item to be predicted is passed in. Probability Model 
def model_prediction_proba(item, dv, model):
    X = dv.transform([item])
    y_pred = model.predict_proba(X)[:, 1]
    return y_pred[0]

# %%
model_prediction(item,dv,dt)
# Out:
# 'canceled'

# %%
actual
# Out:
# array(['canceled'], dtype=object)

# %%
model_prediction_proba(item,dv,dt)
# Out:
# 0.3701403266620658

# %%
# How to convert any pandas row into a dictionary... needed for predictions
# This will give you a template that you can manipulate to create predictions with new values
df_train_full.iloc[[2]].to_dict('records')[0]
# Out:
# {'booking_id': 'inn36186',
#  'no_of_adults': 2,
#  'no_of_children': 0,
#  'no_of_weekend_nights': 1,
#  'no_of_week_nights': 4,
#  'type_of_meal_plan': 'meal_plan_1',
#  'required_car_parking_space': 0,
#  'room_type_reserved': 'room_type_1',
#  'lead_time': 141,
#  'arrival_year': 2018,
#  'arrival_month': 7,
#  'arrival_date': 13,
#  'market_segment_type': 'offline',
#  'repeated_guest': 0,
#  'no_of_previous_cancellations': 0,
#  'no_of_previous_bookings_not_canceled': 0,
#  'avg_price_per_room': 72.25,
#  'no_of_special_requests': 2}

# %%
# Hyperparameter Tuning... light...
# Look at the model parameters.   You can tune these.
dt.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': 4,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 3,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': 42,
#  'splitter': 'best'}

# %%
## Program crashed thrice , to re-run with different data set
